# %% [markdown]
# # Text Processing
#
# ## Capturing Text Data

# %% [markdown]
# ### Plain Text

# %%
import os

# Read in a plain text file
with open(os.path.join("data","hieroglyph.txt"),"r") as f:
    text = f.read()
    print(text)

# %% [markdown]
# ### Tabular Data

# %%
import pandas as pd

# Extract text column from a dataframe
df = pd.read_csv(os.path.join("data", "news.csv"))
df.head()[['publisher', 'title']]

# Convert text column to a lowercase
df["title"] = df["title"].str.lower()
df.head()[['publisher', 'title']]

# %% [markdown]
# ### Online Resource

# %%
import requests
import json

# Fetch data from a REST API
r = requests.get("https://quotes.rest/qod.json")
res = r.json()
print(json.dumps(res,indent=4))

# Extract relevant object and field
q = res["contents"]["quotes"][0]
print(q["quote"], "\n--", q["author"])

# %% [markdown]
# ### Cleaning

# %%
import requests

# Fetch a web page
r = requests.get("https://news.ycombinator.com")
print(r.text)
# Out:
# <html lang="en" op="news"><head><meta name="referrer" content="origin"><meta name="viewport" content="width=device-width, initial-scale=1.0"><link rel="stylesheet" type="text/css" href="news.css?wRBQvoWTalI3lUyNpVaE">
#         <link rel="shortcut icon" href="favicon.ico">
#           <link rel="alternate" type="application/rss+xml" title="RSS" href="rss">
#         <title>Hacker News</title></head><body><center><table id="hnmain" border="0" cellpadding="0" cellspacing="0" width="85%" bgcolor="#f6f6ef">
#         <tr><td bgcolor="#ff6600"><table border="0" cellpadding="0" cellspacing="0" width="100%" style="padding:2px"><tr><td style="width:18px;padding-right:4px"><a href="https://news.ycombinator.com"><img src="y18.gif" width="18" height="18" style="border:1px white solid;"></a></td>
#                   <td style="line-height:12pt; height:10px;"><span class="pagetop"><b class="hnname"><a href="news">Hacker News</a></b>
#               <a href="newest">new</a> | <a href="front">past</a> | <a href="newcomments">comments</a> | <a href="ask">ask</a> | <a href="show">show</a> | <a href="jobs">jobs</a> | <a href="submit">submit</a>            </span></td><td style="text-align:right;padding-right:4px;"><span class="pagetop">
#                               <a href="login?goto=news">login</a>
#                           </span></td>
#               </tr></table></td></tr>
# <tr id="pagespace" title="" style="height:10px"></tr><tr><td><table border="0" cellpadding="0" cellspacing="0" class="itemlist">
#               <tr class='athing' id='27313284'>
#       <td align="right" valign="top" class="title"><span class="rank">1.</span></td>      <td valign="top" class="votelinks"><center><a id='up_27313284' href='vote?id=27313284&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://github.com/livewire-ui/spotlight/issues/25" class="storylink">The phrase “welcome back” on a page causes Safari to autofill a password</a><span class="sitebit comhead"> (<a href="from?site=github.com/livewire-ui"><span class="sitestr">github.com/livewire-ui</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_27313284">259 points</span> by <a href="user?id=knorthfield" class="hnuser">knorthfield</a> <span class="age"><a href="item?id=27313284">2 hours ago</a></span> <span id="unv_27313284"></span> | <a href="hide?id=27313284&amp;goto=news">hide</a> | <a href="item?id=27313284">145&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='27313686'>
#       <td align="right" valign="top" class="title"><span class="rank">2.</span></td>      <td valign="top" class="votelinks"><center><a id='up_27313686' href='vote?id=27313686&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://www.bbc.co.uk/news/uk-england-birmingham-57280115" class="storylink">Sandwell Bitcoin mine found stealing electricity</a><span class="sitebit comhead"> (<a href="from?site=bbc.co.uk"><span class="sitestr">bbc.co.uk</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_27313686">52 points</span> by <a href="user?id=frereubu" class="hnuser">frereubu</a> <span class="age"><a href="item?id=27313686">1 hour ago</a></span> <span id="unv_27313686"></span> | <a href="hide?id=27313686&amp;goto=news">hide</a> | <a href="item?id=27313686">42&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='27310349'>
#       <td align="right" valign="top" class="title"><span class="rank">3.</span></td>      <td valign="top" class="votelinks"><center><a id='up_27310349' href='vote?id=27310349&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://www.fastly.com/blog/quic-is-now-rfc-9000" class="storylink">QUIC is now RFC 9000</a><span class="sitebit comhead"> (<a href="from?site=fastly.com"><span class="sitestr">fastly.com</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_27310349">411 points</span> by <a href="user?id=blucell" class="hnuser">blucell</a> <span class="age"><a href="item?id=27310349">11 hours ago</a></span> <span id="unv_27310349"></span> | <a href="hide?id=27310349&amp;goto=news">hide</a> | <a href="item?id=27310349">118&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='27311964'>
#       <td align="right" valign="top" class="title"><span class="rank">4.</span></td>      <td valign="top" class="votelinks"><center><a id='up_27311964' href='vote?id=27311964&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://boringavatars.com/" class="storylink">Boring Avatars – React library to generate custom avatars</a><span class="sitebit comhead"> (<a href="from?site=boringavatars.com"><span class="sitestr">boringavatars.com</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_27311964">201 points</span> by <a href="user?id=arnklint" class="hnuser">arnklint</a> <span class="age"><a href="item?id=27311964">7 hours ago</a></span> <span id="unv_27311964"></span> | <a href="hide?id=27311964&amp;goto=news">hide</a> | <a href="item?id=27311964">43&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='27313294'>
#       <td align="right" valign="top" class="title"><span class="rank">5.</span></td>      <td valign="top" class="votelinks"><center><a id='up_27313294' href='vote?id=27313294&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://www.adacore.com/download" class="storylink">Gnat 2021 GPL Community Edition Ada 202x compiler released</a><span class="sitebit comhead"> (<a href="from?site=adacore.com"><span class="sitestr">adacore.com</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_27313294">34 points</span> by <a href="user?id=berkeleynerd" class="hnuser">berkeleynerd</a> <span class="age"><a href="item?id=27313294">2 hours ago</a></span> <span id="unv_27313294"></span> | <a href="hide?id=27313294&amp;goto=news">hide</a> | <a href="item?id=27313294">9&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='27313895'>
#       <td align="right" valign="top" class="title"><span class="rank">6.</span></td>      <td valign="top" class="votelinks"><center><a id='up_27313895' href='vote?id=27313895&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://www.ft.com/content/4169ea4b-d6d7-4a2e-bc91-480550c2f539" class="storylink">The rise of crypto laundries: how criminals cash out of Bitcoin</a><span class="sitebit comhead"> (<a href="from?site=ft.com"><span class="sitestr">ft.com</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_27313895">54 points</span> by <a href="user?id=tokyoseb" class="hnuser">tokyoseb</a> <span class="age"><a href="item?id=27313895">1 hour ago</a></span> <span id="unv_27313895"></span> | <a href="hide?id=27313895&amp;goto=news">hide</a> | <a href="item?id=27313895">30&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='27314332'>
#       <td align="right" valign="top" class="title"><span class="rank">7.</span></td>      <td></td><td class="title"><a href="https://www.workatastartup.com/jobs/29595" class="storylink" rel="nofollow">Cortex (YC W20) Is Hiring Founding Engineers</a><span class="sitebit comhead"> (<a href="from?site=workatastartup.com"><span class="sitestr">workatastartup.com</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="age"><a href="item?id=27314332">18 minutes ago</a></span> | <a href="hide?id=27314332&amp;goto=news">hide</a>      </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='27313531'>
#       <td align="right" valign="top" class="title"><span class="rank">8.</span></td>      <td valign="top" class="votelinks"><center><a id='up_27313531' href='vote?id=27313531&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://tidbits.com/2021/05/20/extracting-data-from-an-old-ios-app-broken-by-ios-14-5/" class="storylink">Extracting Data from an Old iOS App Broken by iOS 14.5</a><span class="sitebit comhead"> (<a href="from?site=tidbits.com"><span class="sitestr">tidbits.com</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_27313531">22 points</span> by <a href="user?id=pcr910303" class="hnuser">pcr910303</a> <span class="age"><a href="item?id=27313531">2 hours ago</a></span> <span id="unv_27313531"></span> | <a href="hide?id=27313531&amp;goto=news">hide</a> | <a href="item?id=27313531">11&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='27299363'>
#       <td align="right" valign="top" class="title"><span class="rank">9.</span></td>      <td valign="top" class="votelinks"><center><a id='up_27299363' href='vote?id=27299363&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://japan-forward.com/goodbye-to-the-future-the-last-days-of-tokyos-nakagin-capsule-tower/" class="storylink">The Last Days of Tokyo’s Nakagin Capsule Tower</a><span class="sitebit comhead"> (<a href="from?site=japan-forward.com"><span class="sitestr">japan-forward.com</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_27299363">172 points</span> by <a href="user?id=lieuzh" class="hnuser">lieuzh</a> <span class="age"><a href="item?id=27299363">11 hours ago</a></span> <span id="unv_27299363"></span> | <a href="hide?id=27299363&amp;goto=news">hide</a> | <a href="item?id=27299363">75&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='27312169'>
#       <td align="right" valign="top" class="title"><span class="rank">10.</span></td>      <td valign="top" class="votelinks"><center><a id='up_27312169' href='vote?id=27312169&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://spectrum.ieee.org/automaton/robotics/space-robots/mars-helicopter-lands-safely-after-serious-inflight-anomaly" class="storylink">Mars Helicopter Lands Safely After Serious In-Flight Anomaly</a><span class="sitebit comhead"> (<a href="from?site=ieee.org"><span class="sitestr">ieee.org</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_27312169">176 points</span> by <a href="user?id=tmfi" class="hnuser">tmfi</a> <span class="age"><a href="item?id=27312169">6 hours ago</a></span> <span id="unv_27312169"></span> | <a href="hide?id=27312169&amp;goto=news">hide</a> | <a href="item?id=27312169">66&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='27301879'>
#       <td align="right" valign="top" class="title"><span class="rank">11.</span></td>      <td valign="top" class="votelinks"><center><a id='up_27301879' href='vote?id=27301879&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://joust.life/" class="storylink" rel="nofollow">Show HN: I Built Multiplayer Deathmatch Joust</a><span class="sitebit comhead"> (<a href="from?site=joust.life"><span class="sitestr">joust.life</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_27301879">13 points</span> by <a href="user?id=jasonkester" class="hnuser">jasonkester</a> <span class="age"><a href="item?id=27301879">2 hours ago</a></span> <span id="unv_27301879"></span> | <a href="hide?id=27301879&amp;goto=news">hide</a> | <a href="item?id=27301879">1&nbsp;comment</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='27290471'>
#       <td align="right" valign="top" class="title"><span class="rank">12.</span></td>      <td valign="top" class="votelinks"><center><a id='up_27290471' href='vote?id=27290471&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://techcrunch.com/2021/05/25/call-it-a-comeback-turntable-fm-raises-7-5m/" class="storylink">Call it a comeback: Turntable.fm raises $7.5M</a><span class="sitebit comhead"> (<a href="from?site=techcrunch.com"><span class="sitestr">techcrunch.com</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_27290471">54 points</span> by <a href="user?id=jbredeche" class="hnuser">jbredeche</a> <span class="age"><a href="item?id=27290471">7 hours ago</a></span> <span id="unv_27290471"></span> | <a href="hide?id=27290471&amp;goto=news">hide</a> | <a href="item?id=27290471">38&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='27299787'>
#       <td align="right" valign="top" class="title"><span class="rank">13.</span></td>      <td valign="top" class="votelinks"><center><a id='up_27299787' href='vote?id=27299787&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://publicdomainreview.org/collection/the-woman-and-the-car" class="storylink">On the Road: The Woman and the Car (1909)</a><span class="sitebit comhead"> (<a href="from?site=publicdomainreview.org"><span class="sitestr">publicdomainreview.org</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_27299787">12 points</span> by <a href="user?id=samclemens" class="hnuser">samclemens</a> <span class="age"><a href="item?id=27299787">4 hours ago</a></span> <span id="unv_27299787"></span> | <a href="hide?id=27299787&amp;goto=news">hide</a> | <a href="item?id=27299787">discuss</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='27299964'>
#       <td align="right" valign="top" class="title"><span class="rank">14.</span></td>      <td valign="top" class="votelinks"><center><a id='up_27299964' href='vote?id=27299964&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://www.wsj.com/articles/americans-are-on-the-move-their-stuff-doesnt-always-follow-11622050745" class="storylink">Americans are on the move, but their stuff doesn’t always follow</a><span class="sitebit comhead"> (<a href="from?site=wsj.com"><span class="sitestr">wsj.com</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_27299964">61 points</span> by <a href="user?id=CaliforniaKarl" class="hnuser">CaliforniaKarl</a> <span class="age"><a href="item?id=27299964">9 hours ago</a></span> <span id="unv_27299964"></span> | <a href="hide?id=27299964&amp;goto=news">hide</a> | <a href="item?id=27299964">162&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='27289341'>
#       <td align="right" valign="top" class="title"><span class="rank">15.</span></td>      <td valign="top" class="votelinks"><center><a id='up_27289341' href='vote?id=27289341&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://www.reuters.com/world/asia-pacific/first-tasmanian-devils-born-wild-australia-mainland-3000-years-2021-05-26/" class="storylink">First Tasmanian Devils born in the wild of Australia mainland in 3k years</a><span class="sitebit comhead"> (<a href="from?site=reuters.com"><span class="sitestr">reuters.com</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_27289341">156 points</span> by <a href="user?id=pseudolus" class="hnuser">pseudolus</a> <span class="age"><a href="item?id=27289341">13 hours ago</a></span> <span id="unv_27289341"></span> | <a href="hide?id=27289341&amp;goto=news">hide</a> | <a href="item?id=27289341">50&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='27310247'>
#       <td align="right" valign="top" class="title"><span class="rank">16.</span></td>      <td valign="top" class="votelinks"><center><a id='up_27310247' href='vote?id=27310247&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://github.com/ClickHouse/ClickHouse" class="storylink">ClickHouse: An open-source column-oriented database management system</a><span class="sitebit comhead"> (<a href="from?site=github.com/clickhouse"><span class="sitestr">github.com/clickhouse</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_27310247">133 points</span> by <a href="user?id=tosh" class="hnuser">tosh</a> <span class="age"><a href="item?id=27310247">12 hours ago</a></span> <span id="unv_27310247"></span> | <a href="hide?id=27310247&amp;goto=news">hide</a> | <a href="item?id=27310247">31&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='27311594'>
#       <td align="right" valign="top" class="title"><span class="rank">17.</span></td>      <td valign="top" class="votelinks"><center><a id='up_27311594' href='vote?id=27311594&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="http://www.tvdawn.com/earliest-tv/phonovision-experiments-1927-28/the-recovered-images/" class="storylink">Oldest recovered TV images (2013)</a><span class="sitebit comhead"> (<a href="from?site=tvdawn.com"><span class="sitestr">tvdawn.com</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_27311594">47 points</span> by <a href="user?id=marcodiego" class="hnuser">marcodiego</a> <span class="age"><a href="item?id=27311594">8 hours ago</a></span> <span id="unv_27311594"></span> | <a href="hide?id=27311594&amp;goto=news">hide</a> | <a href="item?id=27311594">17&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='27288598'>
#       <td align="right" valign="top" class="title"><span class="rank">18.</span></td>      <td valign="top" class="votelinks"><center><a id='up_27288598' href='vote?id=27288598&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://spdk.io/news/2021/05/06/nvme-80m-iops/" class="storylink">80M I/O Per Second with a Standard 2U System</a><span class="sitebit comhead"> (<a href="from?site=spdk.io"><span class="sitestr">spdk.io</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_27288598">62 points</span> by <a href="user?id=pbalcer" class="hnuser">pbalcer</a> <span class="age"><a href="item?id=27288598">10 hours ago</a></span> <span id="unv_27288598"></span> | <a href="hide?id=27288598&amp;goto=news">hide</a> | <a href="item?id=27288598">21&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='27299575'>
#       <td align="right" valign="top" class="title"><span class="rank">19.</span></td>      <td valign="top" class="votelinks"><center><a id='up_27299575' href='vote?id=27299575&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://revolutiontalk.substack.com/p/nonfiction" class="storylink">The art of reading non-fiction non-linearly</a><span class="sitebit comhead"> (<a href="from?site=revolutiontalk.substack.com"><span class="sitestr">revolutiontalk.substack.com</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_27299575">27 points</span> by <a href="user?id=pgrddy" class="hnuser">pgrddy</a> <span class="age"><a href="item?id=27299575">5 hours ago</a></span> <span id="unv_27299575"></span> | <a href="hide?id=27299575&amp;goto=news">hide</a> | <a href="item?id=27299575">4&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='27301129'>
#       <td align="right" valign="top" class="title"><span class="rank">20.</span></td>      <td valign="top" class="votelinks"><center><a id='up_27301129' href='vote?id=27301129&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://phys.org/news/2021-05-validate-possibility-helium-jupiter-saturn.html" class="storylink">Experiments validate the possibility of helium rain inside Jupiter and Saturn</a><span class="sitebit comhead"> (<a href="from?site=phys.org"><span class="sitestr">phys.org</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_27301129">34 points</span> by <a href="user?id=dnetesn" class="hnuser">dnetesn</a> <span class="age"><a href="item?id=27301129">8 hours ago</a></span> <span id="unv_27301129"></span> | <a href="hide?id=27301129&amp;goto=news">hide</a> | <a href="item?id=27301129">12&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='27302074'>
#       <td align="right" valign="top" class="title"><span class="rank">21.</span></td>      <td valign="top" class="votelinks"><center><a id='up_27302074' href='vote?id=27302074&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://twitter.com/Kristy_Viers/status/1287189581926981634" class="storylink">How I, as someone who is visually impaired, use my iPhone (2020)</a><span class="sitebit comhead"> (<a href="from?site=twitter.com/kristy_viers"><span class="sitestr">twitter.com/kristy_viers</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_27302074">779 points</span> by <a href="user?id=eevilspock" class="hnuser">eevilspock</a> <span class="age"><a href="item?id=27302074">1 day ago</a></span> <span id="unv_27302074"></span> | <a href="hide?id=27302074&amp;goto=news">hide</a> | <a href="item?id=27302074">219&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='27299038'>
#       <td align="right" valign="top" class="title"><span class="rank">22.</span></td>      <td valign="top" class="votelinks"><center><a id='up_27299038' href='vote?id=27299038&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://www.washingtonpost.com/local/obituaries/eric-carle-dead/2021/05/26/cbb39414-2234-11e4-8593-da634b334390_story.html" class="storylink">Eric Carle has died</a><span class="sitebit comhead"> (<a href="from?site=washingtonpost.com"><span class="sitestr">washingtonpost.com</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_27299038">457 points</span> by <a href="user?id=divbzero" class="hnuser">divbzero</a> <span class="age"><a href="item?id=27299038">19 hours ago</a></span> <span id="unv_27299038"></span> | <a href="hide?id=27299038&amp;goto=news">hide</a> | <a href="item?id=27299038">153&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='27311198'>
#       <td align="right" valign="top" class="title"><span class="rank">23.</span></td>      <td valign="top" class="votelinks"><center><a id='up_27311198' href='vote?id=27311198&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://ma.tt/2021/05/wordpress-18/" class="storylink">WordPress 18</a><span class="sitebit comhead"> (<a href="from?site=ma.tt"><span class="sitestr">ma.tt</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_27311198">195 points</span> by <a href="user?id=gmays" class="hnuser">gmays</a> <span class="age"><a href="item?id=27311198">9 hours ago</a></span> <span id="unv_27311198"></span> | <a href="hide?id=27311198&amp;goto=news">hide</a> | <a href="item?id=27311198">168&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='27310645'>
#       <td align="right" valign="top" class="title"><span class="rank">24.</span></td>      <td valign="top" class="votelinks"><center><a id='up_27310645' href='vote?id=27310645&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://www.virtuozzo.com/connect/details/blog/view/virtuozzos-mature-linux-distribution-vzlinux-now-available-to-public.html" class="storylink">Virtuozzo’s Mature Linux Distribution VzLinux Now Available to Public</a><span class="sitebit comhead"> (<a href="from?site=virtuozzo.com"><span class="sitestr">virtuozzo.com</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_27310645">27 points</span> by <a href="user?id=merlinscholz" class="hnuser">merlinscholz</a> <span class="age"><a href="item?id=27310645">11 hours ago</a></span> <span id="unv_27310645"></span> | <a href="hide?id=27310645&amp;goto=news">hide</a> | <a href="item?id=27310645">5&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='27308982'>
#       <td align="right" valign="top" class="title"><span class="rank">25.</span></td>      <td valign="top" class="votelinks"><center><a id='up_27308982' href='vote?id=27308982&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://macwright.com/2020/05/10/spa-fatigue.html" class="storylink">Second-guessing the modern web (2020)</a><span class="sitebit comhead"> (<a href="from?site=macwright.com"><span class="sitestr">macwright.com</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_27308982">278 points</span> by <a href="user?id=tosh" class="hnuser">tosh</a> <span class="age"><a href="item?id=27308982">14 hours ago</a></span> <span id="unv_27308982"></span> | <a href="hide?id=27308982&amp;goto=news">hide</a> | <a href="item?id=27308982">213&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='27292219'>
#       <td align="right" valign="top" class="title"><span class="rank">26.</span></td>      <td valign="top" class="votelinks"><center><a id='up_27292219' href='vote?id=27292219&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://blog.nikitas.link/have-you-ever-hurt-yourself-from-your-own-code" class="storylink">Have you ever hurt yourself from your own code?</a><span class="sitebit comhead"> (<a href="from?site=nikitas.link"><span class="sitestr">nikitas.link</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_27292219">574 points</span> by <a href="user?id=its_nikita" class="hnuser">its_nikita</a> <span class="age"><a href="item?id=27292219">1 day ago</a></span> <span id="unv_27292219"></span> | <a href="hide?id=27292219&amp;goto=news">hide</a> | <a href="item?id=27292219">389&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='27303881'>
#       <td align="right" valign="top" class="title"><span class="rank">27.</span></td>      <td valign="top" class="votelinks"><center><a id='up_27303881' href='vote?id=27303881&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://antiqueradio.org/welcome.htm" class="storylink">Phil's Old Radios</a><span class="sitebit comhead"> (<a href="from?site=antiqueradio.org"><span class="sitestr">antiqueradio.org</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_27303881">117 points</span> by <a href="user?id=js2" class="hnuser">js2</a> <span class="age"><a href="item?id=27303881">21 hours ago</a></span> <span id="unv_27303881"></span> | <a href="hide?id=27303881&amp;goto=news">hide</a> | <a href="item?id=27303881">33&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='27312564'>
#       <td align="right" valign="top" class="title"><span class="rank">28.</span></td>      <td valign="top" class="votelinks"><center><a id='up_27312564' href='vote?id=27312564&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://github.com/TaKO8Ki/awesome-rewrite-it-in-rust" class="storylink">Replacements for existing software written in Rust</a><span class="sitebit comhead"> (<a href="from?site=github.com/tako8ki"><span class="sitestr">github.com/tako8ki</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_27312564">67 points</span> by <a href="user?id=prabir" class="hnuser">prabir</a> <span class="age"><a href="item?id=27312564">5 hours ago</a></span> <span id="unv_27312564"></span> | <a href="hide?id=27312564&amp;goto=news">hide</a> | <a href="item?id=27312564">74&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='27303783'>
#       <td align="right" valign="top" class="title"><span class="rank">29.</span></td>      <td valign="top" class="votelinks"><center><a id='up_27303783' href='vote?id=27303783&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://github.com/nocodb/nocodb" class="storylink">Show HN: NocoDB – The Open Source Airtable Alternative</a><span class="sitebit comhead"> (<a href="from?site=github.com/nocodb"><span class="sitestr">github.com/nocodb</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_27303783">505 points</span> by <a href="user?id=nocodb" class="hnuser">nocodb</a> <span class="age"><a href="item?id=27303783">21 hours ago</a></span> <span id="unv_27303783"></span> | <a href="hide?id=27303783&amp;goto=news">hide</a> | <a href="item?id=27303783">138&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#                 <tr class='athing' id='27307977'>
#       <td align="right" valign="top" class="title"><span class="rank">30.</span></td>      <td valign="top" class="votelinks"><center><a id='up_27307977' href='vote?id=27307977&amp;how=up&amp;goto=news'><div class='votearrow' title='upvote'></div></a></center></td><td class="title"><a href="https://www.celinehh.com/seed-raise-how-to" class="storylink">How I raised a $5.1M seed as a first-time, female, solo founder for a biotech co</a><span class="sitebit comhead"> (<a href="from?site=celinehh.com"><span class="sitestr">celinehh.com</span></a>)</span></td></tr><tr><td colspan="2"></td><td class="subtext">
#         <span class="score" id="score_27307977">247 points</span> by <a href="user?id=walterbell" class="hnuser">walterbell</a> <span class="age"><a href="item?id=27307977">15 hours ago</a></span> <span id="unv_27307977"></span> | <a href="hide?id=27307977&amp;goto=news">hide</a> | <a href="item?id=27307977">195&nbsp;comments</a>              </td></tr>
#       <tr class="spacer" style="height:5px"></tr>
#             <tr class="morespace" style="height:10px"></tr><tr><td colspan="2"></td><td class="title"><a href="news?p=2" class="morelink" rel="next">More</a></td></tr>
#   </table>
# </td></tr>
# <tr><td><img src="s.gif" height="10" width="0"><table width="100%" cellspacing="0" cellpadding="1"><tr><td bgcolor="#ff6600"></td></tr></table><br><center><span class="yclinks"><a href="newsguidelines.html">Guidelines</a>
#         | <a href="newsfaq.html">FAQ</a>
#         | <a href="lists">Lists</a>
#         | <a href="https://github.com/HackerNews/API">API</a>
#         | <a href="security.html">Security</a>
#         | <a href="http://www.ycombinator.com/legal/">Legal</a>
#         | <a href="http://www.ycombinator.com/apply/">Apply to YC</a>
#         | <a href="mailto:hn@ycombinator.com">Contact</a></span><br><br><form method="get" action="//hn.algolia.com/">Search:
#           <input type="text" name="q" value="" size="17" autocorrect="off" spellcheck="false" autocapitalize="off" autocomplete="false"></form>
#             </center></td></tr>
#       </table></center></body><script type='text/javascript' src='hn.js?wRBQvoWTalI3lUyNpVaE'></script></html>

# %%
import re

# Remove HTML tags using RegEx
pattern = re.compile(r'<.*?>')  # tags look like <...>
print(pattern.sub('',r.text))   # replace them with blank
# Out:
#
#
#         Hacker News
#
#                   Hacker News
#               new | past | comments | ask | show | jobs | submit
#                               login
#
#
#
#
#       1.      The phrase “welcome back” on a page causes Safari to autofill a password (github.com/livewire-ui)
#         259 points by knorthfield 2 hours ago  | hide | 145&nbsp;comments
#
#
#       2.      Sandwell Bitcoin mine found stealing electricity (bbc.co.uk)
#         52 points by frereubu 1 hour ago  | hide | 42&nbsp;comments
#
#
#       3.      QUIC is now RFC 9000 (fastly.com)
#         411 points by blucell 11 hours ago  | hide | 118&nbsp;comments
#
#
#       4.      Boring Avatars – React library to generate custom avatars (boringavatars.com)
#         201 points by arnklint 7 hours ago  | hide | 43&nbsp;comments
#
#
#       5.      Gnat 2021 GPL Community Edition Ada 202x compiler released (adacore.com)
#         34 points by berkeleynerd 2 hours ago  | hide | 9&nbsp;comments
#
#
#       6.      The rise of crypto laundries: how criminals cash out of Bitcoin (ft.com)
#         54 points by tokyoseb 1 hour ago  | hide | 30&nbsp;comments
#
#
#       7.      Cortex (YC W20) Is Hiring Founding Engineers (workatastartup.com)
#         18 minutes ago | hide
#
#
#       8.      Extracting Data from an Old iOS App Broken by iOS 14.5 (tidbits.com)
#         22 points by pcr910303 2 hours ago  | hide | 11&nbsp;comments
#
#
#       9.      The Last Days of Tokyo’s Nakagin Capsule Tower (japan-forward.com)
#         172 points by lieuzh 11 hours ago  | hide | 75&nbsp;comments
#
#
#       10.      Mars Helicopter Lands Safely After Serious In-Flight Anomaly (ieee.org)
#         176 points by tmfi 6 hours ago  | hide | 66&nbsp;comments
#
#
#       11.      Show HN: I Built Multiplayer Deathmatch Joust (joust.life)
#         13 points by jasonkester 2 hours ago  | hide | 1&nbsp;comment
#
#
#       12.      Call it a comeback: Turntable.fm raises $7.5M (techcrunch.com)
#         54 points by jbredeche 7 hours ago  | hide | 38&nbsp;comments
#
#
#       13.      On the Road: The Woman and the Car (1909) (publicdomainreview.org)
#         12 points by samclemens 4 hours ago  | hide | discuss
#
#
#       14.      Americans are on the move, but their stuff doesn’t always follow (wsj.com)
#         61 points by CaliforniaKarl 9 hours ago  | hide | 162&nbsp;comments
#
#
#       15.      First Tasmanian Devils born in the wild of Australia mainland in 3k years (reuters.com)
#         156 points by pseudolus 13 hours ago  | hide | 50&nbsp;comments
#
#
#       16.      ClickHouse: An open-source column-oriented database management system (github.com/clickhouse)
#         133 points by tosh 12 hours ago  | hide | 31&nbsp;comments
#
#
#       17.      Oldest recovered TV images (2013) (tvdawn.com)
#         47 points by marcodiego 8 hours ago  | hide | 17&nbsp;comments
#
#
#       18.      80M I/O Per Second with a Standard 2U System (spdk.io)
#         62 points by pbalcer 10 hours ago  | hide | 21&nbsp;comments
#
#
#       19.      The art of reading non-fiction non-linearly (revolutiontalk.substack.com)
#         27 points by pgrddy 5 hours ago  | hide | 4&nbsp;comments
#
#
#       20.      Experiments validate the possibility of helium rain inside Jupiter and Saturn (phys.org)
#         34 points by dnetesn 8 hours ago  | hide | 12&nbsp;comments
#
#
#       21.      How I, as someone who is visually impaired, use my iPhone (2020) (twitter.com/kristy_viers)
#         779 points by eevilspock 1 day ago  | hide | 219&nbsp;comments
#
#
#       22.      Eric Carle has died (washingtonpost.com)
#         457 points by divbzero 19 hours ago  | hide | 153&nbsp;comments
#
#
#       23.      WordPress 18 (ma.tt)
#         195 points by gmays 9 hours ago  | hide | 168&nbsp;comments
#
#
#       24.      Virtuozzo’s Mature Linux Distribution VzLinux Now Available to Public (virtuozzo.com)
#         27 points by merlinscholz 11 hours ago  | hide | 5&nbsp;comments
#
#
#       25.      Second-guessing the modern web (2020) (macwright.com)
#         278 points by tosh 14 hours ago  | hide | 213&nbsp;comments
#
#
#       26.      Have you ever hurt yourself from your own code? (nikitas.link)
#         574 points by its_nikita 1 day ago  | hide | 389&nbsp;comments
#
#
#       27.      Phil's Old Radios (antiqueradio.org)
#         117 points by js2 21 hours ago  | hide | 33&nbsp;comments
#
#
#       28.      Replacements for existing software written in Rust (github.com/tako8ki)
#         67 points by prabir 5 hours ago  | hide | 74&nbsp;comments
#
#
#       29.      Show HN: NocoDB – The Open Source Airtable Alternative (github.com/nocodb)
#         505 points by nocodb 21 hours ago  | hide | 138&nbsp;comments
#
#
#       30.      How I raised a $5.1M seed as a first-time, female, solo founder for a biotech co (celinehh.com)
#         247 points by walterbell 15 hours ago  | hide | 195&nbsp;comments
#
#             More
#
#
# Guidelines
#         | FAQ
#         | Lists
#         | API
#         | Security
#         | Legal
#         | Apply to YC
#         | ContactSearch:

# %%
from bs4 import BeautifulSoup

# Remove HTML tags using Beautiful Soup library
soup = BeautifulSoup(r.text, "html5lib")
print(soup.get_text())
# Out:
#
#
#         Hacker News
#
#                   Hacker News
#               new | past | comments | ask | show | jobs | submit
#                               login
#
#
#
#
#       1.      The phrase “welcome back” on a page causes Safari to autofill a password (github.com/livewire-ui)
#         259 points by knorthfield 2 hours ago  | hide | 145 comments
#
#
#       2.      Sandwell Bitcoin mine found stealing electricity (bbc.co.uk)
#         52 points by frereubu 1 hour ago  | hide | 42 comments
#
#
#       3.      QUIC is now RFC 9000 (fastly.com)
#         411 points by blucell 11 hours ago  | hide | 118 comments
#
#
#       4.      Boring Avatars – React library to generate custom avatars (boringavatars.com)
#         201 points by arnklint 7 hours ago  | hide | 43 comments
#
#
#       5.      Gnat 2021 GPL Community Edition Ada 202x compiler released (adacore.com)
#         34 points by berkeleynerd 2 hours ago  | hide | 9 comments
#
#
#       6.      The rise of crypto laundries: how criminals cash out of Bitcoin (ft.com)
#         54 points by tokyoseb 1 hour ago  | hide | 30 comments
#
#
#       7.      Cortex (YC W20) Is Hiring Founding Engineers (workatastartup.com)
#         18 minutes ago | hide
#
#
#       8.      Extracting Data from an Old iOS App Broken by iOS 14.5 (tidbits.com)
#         22 points by pcr910303 2 hours ago  | hide | 11 comments
#
#
#       9.      The Last Days of Tokyo’s Nakagin Capsule Tower (japan-forward.com)
#         172 points by lieuzh 11 hours ago  | hide | 75 comments
#
#
#       10.      Mars Helicopter Lands Safely After Serious In-Flight Anomaly (ieee.org)
#         176 points by tmfi 6 hours ago  | hide | 66 comments
#
#
#       11.      Show HN: I Built Multiplayer Deathmatch Joust (joust.life)
#         13 points by jasonkester 2 hours ago  | hide | 1 comment
#
#
#       12.      Call it a comeback: Turntable.fm raises $7.5M (techcrunch.com)
#         54 points by jbredeche 7 hours ago  | hide | 38 comments
#
#
#       13.      On the Road: The Woman and the Car (1909) (publicdomainreview.org)
#         12 points by samclemens 4 hours ago  | hide | discuss
#
#
#       14.      Americans are on the move, but their stuff doesn’t always follow (wsj.com)
#         61 points by CaliforniaKarl 9 hours ago  | hide | 162 comments
#
#
#       15.      First Tasmanian Devils born in the wild of Australia mainland in 3k years (reuters.com)
#         156 points by pseudolus 13 hours ago  | hide | 50 comments
#
#
#       16.      ClickHouse: An open-source column-oriented database management system (github.com/clickhouse)
#         133 points by tosh 12 hours ago  | hide | 31 comments
#
#
#       17.      Oldest recovered TV images (2013) (tvdawn.com)
#         47 points by marcodiego 8 hours ago  | hide | 17 comments
#
#
#       18.      80M I/O Per Second with a Standard 2U System (spdk.io)
#         62 points by pbalcer 10 hours ago  | hide | 21 comments
#
#
#       19.      The art of reading non-fiction non-linearly (revolutiontalk.substack.com)
#         27 points by pgrddy 5 hours ago  | hide | 4 comments
#
#
#       20.      Experiments validate the possibility of helium rain inside Jupiter and Saturn (phys.org)
#         34 points by dnetesn 8 hours ago  | hide | 12 comments
#
#
#       21.      How I, as someone who is visually impaired, use my iPhone (2020) (twitter.com/kristy_viers)
#         779 points by eevilspock 1 day ago  | hide | 219 comments
#
#
#       22.      Eric Carle has died (washingtonpost.com)
#         457 points by divbzero 19 hours ago  | hide | 153 comments
#
#
#       23.      WordPress 18 (ma.tt)
#         195 points by gmays 9 hours ago  | hide | 168 comments
#
#
#       24.      Virtuozzo’s Mature Linux Distribution VzLinux Now Available to Public (virtuozzo.com)
#         27 points by merlinscholz 11 hours ago  | hide | 5 comments
#
#
#       25.      Second-guessing the modern web (2020) (macwright.com)
#         278 points by tosh 14 hours ago  | hide | 213 comments
#
#
#       26.      Have you ever hurt yourself from your own code? (nikitas.link)
#         574 points by its_nikita 1 day ago  | hide | 389 comments
#
#
#       27.      Phil's Old Radios (antiqueradio.org)
#         117 points by js2 21 hours ago  | hide | 33 comments
#
#
#       28.      Replacements for existing software written in Rust (github.com/tako8ki)
#         67 points by prabir 5 hours ago  | hide | 74 comments
#
#
#       29.      Show HN: NocoDB – The Open Source Airtable Alternative (github.com/nocodb)
#         505 points by nocodb 21 hours ago  | hide | 138 comments
#
#
#       30.      How I raised a $5.1M seed as a first-time, female, solo founder for a biotech co (celinehh.com)
#         247 points by walterbell 15 hours ago  | hide | 195 comments
#
#             More
#
#
# Guidelines
#         | FAQ
#         | Lists
#         | API
#         | Security
#         | Legal
#         | Apply to YC
#         | ContactSearch:

# %%
# Find all articles
summaries = soup.find_all("tr",class_="athing")
summaries[0]
# Out:
# <tr class="athing" id="27313284">
#       <td align="right" class="title" valign="top"><span class="rank">1.</span></td>      <td class="votelinks" valign="top"><center><a href="vote?id=27313284&amp;how=up&amp;goto=news" id="up_27313284"><div class="votearrow" title="upvote"></div></a></center></td><td class="title"><a class="storylink" href="https://github.com/livewire-ui/spotlight/issues/25">The phrase “welcome back” on a page causes Safari to autofill a password</a><span class="sitebit comhead"> (<a href="from?site=github.com/livewire-ui"><span class="sitestr">github.com/livewire-ui</span></a>)</span></td></tr>

# %%
# Extract title
summaries[0].find("a", class_="storylink").get_text().strip()
# Out:
# 'The phrase “welcome back” on a page causes Safari to autofill a password'

# %%
# Find all articles, extract titles

articles = []
# for i in range(len(summaries)):
#     articles.append(summaries[i].find("a", class_="storylink").get_text().strip())
summaries = soup.find_all("tr", class_="athing")
for summary in summaries:
    articles.append(summary.find("a", class_="storylink").get_text().strip())

# %%
articles
# Out:
# ['The phrase “welcome back” on a page causes Safari to autofill a password',
#  'Sandwell Bitcoin mine found stealing electricity',
#  'QUIC is now RFC 9000',
#  'Boring Avatars – React library to generate custom avatars',
#  'Gnat 2021 GPL Community Edition Ada 202x compiler released',
#  'The rise of crypto laundries: how criminals cash out of Bitcoin',
#  'Cortex (YC W20) Is Hiring Founding Engineers',
#  'Extracting Data from an Old iOS App Broken by iOS 14.5',
#  'The Last Days of Tokyo’s Nakagin Capsule Tower',
#  'Mars Helicopter Lands Safely After Serious In-Flight Anomaly',
#  'Show HN: I Built Multiplayer Deathmatch Joust',
#  'Call it a comeback: Turntable.fm raises $7.5M',
#  'On the Road: The Woman and the Car (1909)',
#  'Americans are on the move, but their stuff doesn’t always follow',
#  'First Tasmanian Devils born in the wild of Australia mainland in 3k years',
#  'ClickHouse: An open-source column-oriented database management system',
#  'Oldest recovered TV images (2013)',
#  '80M I/O Per Second with a Standard 2U System',
#  'The art of reading non-fiction non-linearly',
#  'Experiments validate the possibility of helium rain inside Jupiter and Saturn',
#  'How I, as someone who is visually impaired, use my iPhone (2020)',
#  'Eric Carle has died',
#  'WordPress 18',
#  'Virtuozzo’s Mature Linux Distribution VzLinux Now Available to Public',
#  'Second-guessing the modern web (2020)',
#  'Have you ever hurt yourself from your own code?',
#  "Phil's Old Radios",
#  'Replacements for existing software written in Rust',
#  'Show HN: NocoDB – The Open Source Airtable Alternative',
#  'How I raised a $5.1M seed as a first-time, female, solo founder for a biotech co']

# %%
r = requests.get("https://scis.smu.edu.sg/master-it-business/analytics-track/curriculum")
print(r.text)
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="ie6 ie" lang="en" dir="ltr"> <![endif]-->
# <!--[if IE 7]>    <html class="ie7 ie" lang="en" dir="ltr"> <![endif]-->
# <!--[if IE 8]>    <html class="ie8 ie" lang="en" dir="ltr"> <![endif]-->
# <!--[if IE 9]>    <html class="ie9 ie" lang="en" dir="ltr"> <![endif]-->
# <!--[if !IE]> --> <html lang="en" dir="ltr" ng-controller="SMUController"> <!-- <![endif]-->
#
# <head>
# <meta http-equiv="X-UA-Compatible" content="IE=Edge,chrome=1">
#   <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# <meta name="Generator" content="Drupal 7 (http://drupal.org)" />
# <link rel="canonical" href="/master-it-business/analytics-track/curriculum" />
# <link rel="shortlink" href="/node/30326" />
# <link rel="shortcut icon" href="https://scis.smu.edu.sg/sites/all/themes/smu/images/smu_favicon.png" type="image/png" />
#   <!-- Set the viewport width to device width for mobile -->
#   <meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no">
#    <meta name="apple-mobile-web-app-capable" content="yes" />
#     <meta name="mobile-web-app-capable" content="yes" />
#     <meta name="apple-mobile-web-app-title" content="ARCIALA" />
#   <title>
#     Analytics Track | School of Computing and Information Systems (SMU)  </title>
#   <link type="text/css" rel="stylesheet" href="https://scis.smu.edu.sg/sites/sis.smu.edu.sg/files/css/css_xE-rWrJf-fncB6ztZfd2huxqgxu4WO-qwma6Xer30m4.css" media="all" />
# <link type="text/css" rel="stylesheet" href="https://scis.smu.edu.sg/sites/sis.smu.edu.sg/files/css/css_lGnaOF7Wrw3DgVdpPNchzzWbI75pZ12eDKWazilZuvg.css" media="all" />
# <link type="text/css" rel="stylesheet" href="https://scis.smu.edu.sg/sites/sis.smu.edu.sg/files/css/css_vTpQd8SsuI2W9OWPdpzyC3cBq70_CQfowvVmwoATH-w.css" media="all" />
# <link type="text/css" rel="stylesheet" href="https://scis.smu.edu.sg/sites/sis.smu.edu.sg/files/css/css_kUp53PLVOE_NVhMYY-IuEA8iL7v3jDmFFVcRxeaLaHk.css" media="all" />
# <link type="text/css" rel="stylesheet" href="https://scis.smu.edu.sg/sites/sis.smu.edu.sg/files/css/css_pi0BN6e9kBtj6M24hhzaXJZLHGXpn83Qq0purruUNVI.css" media="print" />
#   <script type="text/javascript" src="https://scis.smu.edu.sg/sites/all/libraries/respondjs/respond.min.js?qttg02"></script>
# <script type="text/javascript" src="https://scis.smu.edu.sg/sites/all/modules/jquery_update/replace/jquery/1.9/jquery.min.js?v=1.9.1"></script>
# <script type="text/javascript" src="https://scis.smu.edu.sg/misc/jquery-extend-3.4.0.js?v=1.9.1"></script>
# <script type="text/javascript" src="https://scis.smu.edu.sg/misc/jquery-html-prefilter-3.5.0-backport.js?v=1.9.1"></script>
# <script type="text/javascript" src="https://scis.smu.edu.sg/misc/jquery.once.js?v=1.2"></script>
# <script type="text/javascript" src="https://scis.smu.edu.sg/misc/drupal.js?qttg02"></script>
# <script type="text/javascript" src="https://scis.smu.edu.sg/sites/all/modules/jquery_update/replace/ui/ui/minified/jquery.ui.effect.min.js?v=1.10.2"></script>
# <script type="text/javascript" src="/sites/all/libraries/angular/angular.js?qttg02"></script>
# <script type="text/javascript" src="https://scis.smu.edu.sg/sites/all/modules/back_to_top/js/back_to_top.js?qttg02"></script>
# <script type="text/javascript" src="https://scis.smu.edu.sg/sites/all/libraries/colorbox/jquery.colorbox-min.js?qttg02"></script>
# <script type="text/javascript" src="https://scis.smu.edu.sg/sites/all/modules/colorbox/js/colorbox.js?qttg02"></script>
# <script type="text/javascript" src="https://scis.smu.edu.sg/sites/all/modules/colorbox/styles/default/colorbox_style.js?qttg02"></script>
# <script type="text/javascript" src="https://scis.smu.edu.sg/sites/all/modules/colorbox/js/colorbox_load.js?qttg02"></script>
# <script type="text/javascript" src="https://scis.smu.edu.sg/sites/all/modules/smu/smusearch/smusearch.js?qttg02"></script>
# <script type="text/javascript" src="https://scis.smu.edu.sg/sites/all/themes/smubase/packages/bootstrap/js/bootstrap.min.js?qttg02"></script>
# <script type="text/javascript" src="//use.typekit.com/uhs0req.js"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# try{Typekit.load();}catch(e){}
# //--><!]]>
# </script>
# <script type="text/javascript" src="/sites/all/libraries/jquery-touchswipe/jquery.touchSwipe.min.js?qttg02"></script>
# <script type="text/javascript" src="/sites/all/libraries/jquery.easing/jquery.easing.1.3.js?qttg02"></script>
# <script type="text/javascript" src="/sites/all/libraries/jquery-loading-overlay/dist/loading-overlay.min.js?qttg02"></script>
# <script type="text/javascript" src="/sites/all/libraries/responsive-tab/responsive-tabs.js"></script>
# <script type="text/javascript" src="https://scis.smu.edu.sg/sites/all/themes/open_framework/js/open_framework.js?qttg02"></script>
# <script type="text/javascript" src="https://scis.smu.edu.sg/sites/all/themes/open_framework/js/jquery.placeholder.min.js?qttg02"></script>
# <script type="text/javascript" src="https://scis.smu.edu.sg/sites/all/themes/smubase_rev/js/js.js?qttg02"></script>
# <script type="text/javascript" src="https://scis.smu.edu.sg/sites/all/themes/smubase_rev/js/mobilemenu.js?qttg02"></script>
# <script type="text/javascript" src="https://scis.smu.edu.sg/sites/all/themes/smu_pg/js/script.js?qttg02"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"","ajaxPageState":{"theme":"smu_pg","theme_token":"7UCl8c1CYvAWG2TZNt-fpoRLmsOXtZEWl4-m8TIHPfQ","js":{"sites\/all\/libraries\/respondjs\/respond.min.js":1,"sites\/all\/modules\/jquery_update\/replace\/jquery\/1.9\/jquery.min.js":1,"misc\/jquery-extend-3.4.0.js":1,"misc\/jquery-html-prefilter-3.5.0-backport.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"sites\/all\/modules\/jquery_update\/replace\/ui\/ui\/minified\/jquery.ui.effect.min.js":1,"\/sites\/all\/libraries\/angular\/angular.js":1,"sites\/all\/modules\/back_to_top\/js\/back_to_top.js":1,"sites\/all\/libraries\/colorbox\/jquery.colorbox-min.js":1,"sites\/all\/modules\/colorbox\/js\/colorbox.js":1,"sites\/all\/modules\/colorbox\/styles\/default\/colorbox_style.js":1,"sites\/all\/modules\/colorbox\/js\/colorbox_load.js":1,"sites\/all\/modules\/smu\/smusearch\/smusearch.js":1,"sites\/all\/themes\/smubase\/packages\/bootstrap\/js\/bootstrap.min.js":1,"\/\/use.typekit.com\/uhs0req.js":1,"0":1,"\/sites\/all\/libraries\/jquery-touchswipe\/jquery.touchSwipe.min.js":1,"\/sites\/all\/libraries\/jquery.easing\/jquery.easing.1.3.js":1,"\/sites\/all\/libraries\/jquery-loading-overlay\/dist\/loading-overlay.min.js":1,"\/sites\/all\/libraries\/responsive-tab\/responsive-tabs.js":1,"sites\/all\/themes\/open_framework\/js\/open_framework.js":1,"sites\/all\/themes\/open_framework\/js\/jquery.placeholder.min.js":1,"sites\/all\/themes\/smubase_rev\/js\/js.js":1,"sites\/all\/themes\/smubase_rev\/js\/mobilemenu.js":1,"sites\/all\/themes\/smu_pg\/js\/script.js":1},"css":{"modules\/system\/system.base.css":1,"modules\/system\/system.menus.css":1,"modules\/system\/system.messages.css":1,"modules\/system\/system.theme.css":1,"modules\/aggregator\/aggregator.css":1,"sites\/all\/modules\/date\/date_api\/date.css":1,"sites\/all\/modules\/date\/date_popup\/themes\/datepicker.1.7.css":1,"modules\/field\/theme\/field.css":1,"modules\/node\/node.css":1,"sites\/all\/modules\/siteimprove\/css\/siteimprove.css":1,"modules\/user\/user.css":1,"sites\/all\/modules\/views\/css\/views.css":1,"sites\/all\/modules\/back_to_top\/css\/back_to_top.css":1,"sites\/all\/modules\/colorbox\/styles\/default\/colorbox_style.css":1,"sites\/all\/modules\/ctools\/css\/ctools.css":1,"sites\/all\/modules\/facebook_pull\/facebook_pull.css":1,"sites\/all\/themes\/smubase\/packages\/bootstrap\/css\/bootstrap.min.css":1,"sites\/all\/themes\/smubase\/packages\/bootstrap\/css\/bootstrap-theme.min.css":1,"sites\/all\/themes\/smubase\/packages\/font-awesome-4.1.0\/css\/font-awesome.min.css":1,"sites\/all\/themes\/open_framework\/css\/open_framework.css":1,"sites\/all\/themes\/smubase_rev\/css\/global.css":1,"sites\/all\/themes\/smubase_rev\/css\/footer.css":1,"sites\/all\/themes\/smubase_rev\/css\/responsive.css":1,"sites\/all\/themes\/smubase_rev\/css\/feature.css":1,"sites\/all\/themes\/smu_pg\/stylesheets\/styles.css":1,"sites\/all\/themes\/smu_pg\/stylesheets\/custom.css":1,"sites\/all\/themes\/open_framework\/css\/open_framework_print.css":1,"sites\/all\/themes\/smubase_rev\/css\/print.css":1}},"colorbox":{"opacity":"0.85","current":"{current} of {total}","previous":"\u00ab Prev","next":"Next \u00bb","close":"Close","maxWidth":"98%","maxHeight":"98%","fixed":true,"mobiledetect":true,"mobiledevicewidth":"480px"},"better_exposed_filters":{"views":{"information_sessions":{"displays":{"block_2":{"filters":[]}}}}},"back_to_top":{"back_to_top_button_trigger":100,"back_to_top_button_text":"Back to top","#attached":{"library":[["system","ui"]]}}});
# //--><!]]>
# </script>
#   <link href="/sites/all/libraries/jqueryjscrollpane/jquery.jscrollpane.css?cd" media="all" rel="stylesheet" type="text/css" />
#   <script type="text/javascript" src="/sites/all/libraries/jqueryjscrollpane/jquery.jscrollpane.min.js?cded"></script>
# </head>
#
# <body class="html not-front not-logged-in one-sidebar sidebar-second page-node page-node- page-node-30326 node-type-page path-mitb sidebar-3col   content-first   show-breadcrumb    bootstrap-3 font-awesome-4"  >
#
#         <noscript><iframe src="//www.googletagmanager.com/ns.html?id=GTM-PPDXSR"
#       height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
#       <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#       new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#       j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#       '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#       })(window,document,'script','dataLayer','GTM-PPDXSR');</script>
#
#     <a href="#main" class="element-invisible element-focusable">Skip to content</a>
# <a href="#main-nav" class="element-invisible element-focusable" data-target=".nav-collapse" data-toggle="collapse">Skip to navigation</a>
# <!-- /#skipnav -->
#
# <!-- old header -->
#
#
#
#   <div id="header" class="clearfix site-header">
# <!-- CR_TEMP -->
# <div id="announcement" class="container-fluid">
#   <div class="container announcement">
#       <div class="cr-message">
#         <div class="content">
#           <style type="text/css">#announcement {     background: crimson; color:#fff; } #announcement .announcement {     padding: 5px 15px; } #announcement p {     padding: 0;     margin: 0; } #announcement a { color:#fff; } #announcement  .fas.fa-external-link-alt {     margin-left: 5px;     font-size: 10px; }
#           </style>
#           <center>
#             <a href="https://crisisresponse.smu.edu.sg" target="_blank"><strong>Advisories and updates on 2019 Novel Coronavirus (COVID-19)</strong>
#               <i class="fas fa-external-link-alt"></i></a>
#           </center>
#         </div>
#       </div>
#   </div>
# </div>
# <!-- CR_TEMP -->
#     <!-- /#top header,normally for soical icons-->
#     <div id="header-one" class="clearfix header-one">
#       <div class="container">
#             <div class="col-md-12">
#           <!-- div class="cd-dropdown-wrapper pull-right row"> <a class="cd-dropdown-trigger" href="#0">&nbsp;</a>
#                       </div -->
#                                <div class="region region-header clearfix">
#   <div id="block-block-326" class="clearfix block block-block">       <div class="content"> <div class="social-menu">&#13;&#13;
# <span><a href="https://www.facebook.com/MITBSMU" target="_blank" class="facebook" title="Facebook" alt="Facebook"><i class="fa fa-facebook"></i></a></span>&#13;&#13;
# <span><a href="https://www.linkedin.com/in/smu-master-of-it-in-business-a5298085/" target="_blank" class="linkedin" title="LinkedIn" alt="LinkedIn"><i class="fa fa-linkedin"></i></a></span>&#13;&#13;
# <span><a href="mailto:mitb@smu.edu.sg" class="Contact" title="Contact" alt="Contact"><i class="fa fa-envelope"></i></a></span>&#13;&#13;
# <span><a href="//scis.smu.edu.sg/master-it-business/news-events/current-events" class="calendar" title="Calendar" alt="Calendar"><i class="fa fa-calendar"></i></a></span>&#13;&#13;
# <span><a href="https://www.youtube.com/channel/UCP9tOGPsNkPhqfQUQOgtUVQ" target="_blank" class="SIS Youtube Channel" title="SIS Youtube Channel" alt="SIS Youtube Channel"><i class="fa fa-youtube"></i></a></span>&#13;&#13;
# <span><a href="//scis.smu.edu.sg/rss" class="RSS" title="RSS" alt="RSS"><i class="fa fa-rss"></i></a></span>&#13;&#13;
# </div> </div>
# </div></div>
#  <!-- /.region -->
#           <div class="utility-menu">
#   <li class="utility-item connect"><a href="#" role="button" id="connect-menu" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">Connect <i class="fas fa fa-chevron-down"></i></a>
#     <div class="dropdown-menu connect-menu" aria-labelledby="connect-menu">
#       <!-- div class="col-md-4 col-sm-4 col-xs-12 others connect-menu-block no-padding-left no-padding-right">
#         <div class="col-md-12 col-sm-12 col-xs-6 connect-menu-inner">
#           <ul>
#             <li><a href="https://www.smu.edu.sg/contact" target="_blank">Contact</a></li>
#             <li><a href="https://careers.smu.edu.sg/" target="_blank">Careers @ SMU</a></li>
#           </ul>
#         </div>
#         <div class="col-md-12 col-sm-12 col-xs-6 connect-menu-inner">
#           <ul>
#             <li><a href="https://www.smu.edu.sg/career-services/employer-information/recruitment-of-smu-graduates" target="_blank">Hiring from SMU</a></li>
#             <li><a href="https://www.smu.edu.sg/about/smu-degree-diploma-certificate" target="_blank">Verify SMU Certs</a></li>
#           </ul>
#         </div>
#       </div -->
#       <div class="col-md-12 col-sm-12 col-xs-12 connect-menu-block no-padding-left no-padding-right main-links">
#         <div class="col-md-6 col-sm-6 col-xs-6 connect-menu-block-inner">
#           <ul>
#             <li><a href="https://email.smu.edu.sg/" target="_blank">Faculty/Staff Email</a></li>
#             <li><a href="https://live.smu.edu.sg/" target="_blank">Student Email</a></li>
#             <li><a href="https://inet.smu.edu.sg/" target="_blank">iNet Intranet</a></li>
#             <li><a href="https://oasis.smu.edu.sg/" target="_blank">OASIS Intranet</a></li>
#           </ul>
#         </div>
#         <div class="col-md-6 col-sm-6 col-xs-6 connect-menu-block-inner">
#           <ul>
#             <li><a href="https://elearn.smu.edu.sg/" target="_blank">eLearn</a></li>
#             <li><a href="https://inet.smu.edu.sg/sites/extranet" target="_blank">SMU Extranet</a></li>
#             <li><a href="https://ontrac.smu.edu.sg/" target="_blank">OnTrac II</a></li>
#             <li><a href="https://www.google.com/a/smu.edu.sg/ServiceLogin" target="_blank">Google Apps</a></li>
#           </ul>
#         </div>
#       </div>
#       <div class="clearfix">
#       </div>
#     </div>
#   </li>
# </div>
#
#                   <div class="mobile-search-btns hidden-sm hidden-md hidden-lg">
#                     <button class="btn btn-default search-go" data-toggle="collapse" href="#mobile-search" role="button" aria-expanded="false" aria-controls="mobile-search">
#                       <span class="glyphicon glyphicon-search"></span>
#                     </button>
#                      <button class="btn btn-default search-close btn-reset hidden" data-toggle="collapse" href="#mobile-search" role="button" aria-expanded="false" aria-controls="mobile-search">
#                       <span class="glyphicon glyphicon-remove">
#                           <span class="sr-only">Close</span>
#                         </span>
#                     </button>
#                   </div>
#                   <div class="full-search hidden-xs">
#                     <div class="region region-search-box clearfix">
#   <div id="block-smusearch-smusearch-box" class="clearfix block block-smusearch">       <div class="content"> <style>
# #smusearch_dropdown li{ padding-left:10px;}
# </style>
# <form class="smu-integrated-search" id="smu_integrated_search" role="search" method="post" action="">
#   <div class="input-group search-tf search-hide">
#     <input type="text" class="form-control search-tf-input" placeholder="Search..." id="keys" name="keys" autofocus="autofocus">
#
#     <div class="input-group-btn search-type-btn">
#       <button type="button" class="btn btn-default dropdown-toggle" data-toggle="dropdown" tabindex="-1" id="smusearch_cat" name="smusearch_cat"> <span><i class="fas fa fa-chevron-down"></i></span> <span class="sr-only">Toggle Dropdown</span> </button>
#       <ul id="smusearch_dropdown" class="dropdown-menu pull-right">
#         <li>
#           <input name="smusearch_cat_val" type="radio" value="web" checked="checked" id="search-web" class="radio-search">
#           <label for="search-web">This Site</label>
#         </li>
#                 <li>
#           <input name="smusearch_cat_val" type="radio" value="smu" id="search-smu" class="radio-search">
#           <label for="search-smu">SMU Main Site</label>
#         </li>
#
#       </ul>
#     </div>
#     <div class="input-group-btn search-btn">
#       <!--<input type="hidden" id="smusearch_cat_val" name="smusearch_cat_val" />-->
#       <button type="submit" class="btn btn-default search-go"
#                      tabindex="-1" id="smusearch_submit" name="smusearch_submit"><span class="glyphicon glyphicon-search"></span> </button>
# 										 <button type="reset" class="btn btn-default search-close btn-reset hidden-xs">
#                       <span class="glyphicon glyphicon-remove">
#                         <span class="sr-only">Close</span>
#                       </span>
#                     </button>
#     </div>
#
#     <!-- /btn-group -->
#   </div>
#
#   <!-- /input-group -->
#
# </form>
#  </div>
# </div></div>
#  <!-- /.region -->
#
#                   </div>
#
#         </div>
#       </div>
#     </div>
#     <!-- end /#top header-->
#
#           <div id="mobile-search" class="collapse header-mobile-search container-fluid hidden-sm hidden-md hidden-lg">
#               <div class="region region-search-box clearfix">
#   <div class="region region-search-box clearfix">
#   <div id="block-smusearch-smusearch-box" class="clearfix block block-smusearch">       <div class="content"> <style>
# #smusearch_dropdown li{ padding-left:10px;}
# </style>
# <form class="smu-integrated-search" id="smu_integrated_search" role="search" method="post" action="">
#   <div class="input-group search-tf search-hide">
#     <input type="text" class="form-control search-tf-input" placeholder="Search..." id="keys" name="keys" autofocus="autofocus">
#
#     <div class="input-group-btn search-type-btn">
#       <button type="button" class="btn btn-default dropdown-toggle" data-toggle="dropdown" tabindex="-1" id="smusearch_cat" name="smusearch_cat"> <span><i class="fas fa fa-chevron-down"></i></span> <span class="sr-only">Toggle Dropdown</span> </button>
#       <ul id="smusearch_dropdown" class="dropdown-menu pull-right">
#         <li>
#           <input name="smusearch_cat_val" type="radio" value="web" checked="checked" id="search-web" class="radio-search">
#           <label for="search-web">This Site</label>
#         </li>
#                 <li>
#           <input name="smusearch_cat_val" type="radio" value="smu" id="search-smu" class="radio-search">
#           <label for="search-smu">SMU Main Site</label>
#         </li>
#
#       </ul>
#     </div>
#     <div class="input-group-btn search-btn">
#       <!--<input type="hidden" id="smusearch_cat_val" name="smusearch_cat_val" />-->
#       <button type="submit" class="btn btn-default search-go"
#                      tabindex="-1" id="smusearch_submit" name="smusearch_submit"><span class="glyphicon glyphicon-search"></span> </button>
# 										 <button type="reset" class="btn btn-default search-close btn-reset hidden-xs">
#                       <span class="glyphicon glyphicon-remove">
#                         <span class="sr-only">Close</span>
#                       </span>
#                     </button>
#     </div>
#
#     <!-- /btn-group -->
#   </div>
#
#   <!-- /input-group -->
#
# </form>
#  </div>
# </div></div>
#  <!-- /.region -->
# </div>
#  <!-- /.region -->
#
#           </div>
#
#           <div id="header-two" class="header-shadow header-two container-fluid">
#           <div class="obg obg-white"></div>
#             <div class="obg obg-site"></div>
#             <div class="navbar-header-container container">
#               <div class="navbar-header">
#                 <div class="site-branding pull-left">
#                   <div class="ob-smu-logo">
#                     <a target="_blank" href="//www.smu.edu.sg" rel="home" title="Singapore Management University (SMU)" name="top">
#                       <img class="ob-smulogo hidden-xs hidden-sm" alt="Singapore Management University (SMU)" src="/sites/all/themes/smubase_nw2_rev/svg/logo-d-smu.svg" width="153" height="60"><img class="ob-smulogo hidden-lg hidden-md hidden-xs" alt="Singapore Management University (SMU)" src="/sites/all/themes/smubase_nw2_rev/svg/logo-t-smu.svg" width="113" height="60"><img class="ob-smulogo hidden-lg hidden-md hidden-sm" alt="Singapore Management University (SMU)" src="/sites/all/themes/smubase_nw2_rev/svg/logo-m-smu.svg" width="37" height="48">
#                     </a>
#                   </div><div class="ob-bu-logo">
# <a href="/" title="Home" rel="home"><img src="/sites/default/files/site-headers/desktop-tablet/all/logo-dt-scis.svg"  height="60" class="hidden-xs"><img src="/sites/default/files/site-headers/mobile/all/logo-m-scis.svg"  height="48" class="hidden-lg hidden-md hidden-sm"></a>
#                   </div><div class="ob-oblique">
#                     <img src="/sites/all/themes/smubase_nw2_rev/svg/oblique.svg">
#                   </div>
#                 </div>
#
#                 <div class="pull-right hidden-xs hidden-sm">
#                   <h3 class="subheader subheader-2  pg-subhead"></h3>
#                 </div>
#                 <button type="button" class="navbar-toggle pull-right hidden-lg hidden-md hidden-sm" data-toggle="collapse" data-target="#smu-navbar-collapse-nav">
#                   <span class="sr-only">Toggle navigation</span>
#                   <span class="icon-bar"></span>
#                   <span class="icon-bar"></span>
#                   <span class="icon-bar"></span>
#                 </button>
#               </div>
#             </div>
#
#         <!-- main nav-->
#         <div id="main-nav" class="container-fluid">
#             <div class="container">
#             <nav role="navigation">
#               <div class="navbar navbar-inverse navbar-static-top" data-role="navigation">
#                 <div class="navbar-inner-cus">
#                     <div class="collapse navbar-collapse navbar-left" id="smu-navbar-collapse-nav">
#                       <div class="nav navbar-nav">
#                                                                         <div class="region region-navigation clearfix">
#   <div id="block-menu-menu-menu-mitb-new-" class="clearfix block block-menu">     <h2 class="block-title">Menu: MITB (New)</h2>
#       <div class="content"> <ul class="menu nav navbar-nav"><li class="first leaf"><a href="/master-it-business">Master of IT in Business</a></li>
# <li class="expanded dropdown"><a href="/master-it-business/about-mitb-main" class="dropdown-toggle" data-toggle="dropdown" data-target="#">About MITB <span class="caret"></span></a><ul class="dropdown-menu"><li class="first leaf"><a href="/master-it-business/about-mitb-main">Why SMU MITB?</a></li>
# <li class="leaf"><a href="/master-it-business/career-services">Career Services</a></li>
# <li class="leaf"><a href="/master-it-business/graduate-employability">Graduate Employability</a></li>
# <li class="leaf"><a href="/master-it-business/university-partners">University Partners</a></li>
# <li class="leaf"><a href="/master-it-business/research-thought-leadership-articles">Thought Leadership</a></li>
# <li class="leaf"><a href="/master-it-business/mitb-vantage">MITB Vantage</a></li>
# <li class="last expanded dropdown-submenu"><a href="/master-it-business/research/ubpf" class="menu-node-unpublished dropdown-toggle" data-toggle="dropdown" data-target="#">Research</a><ul class="dropdown-menu"><li class="first leaf"><a href="/master-it-business/research/ubpf">Unified Banking Process Framework</a></li>
# <li class="last leaf"><a href="/master-it-business/research-thought-leadership/smu-teaching-bank">SMU Teaching Bank</a></li>
# </ul></li>
# </ul></li>
# <li class="expanded active-trail dropdown"><a href="/master-it-business/analytics-track/curriculum" class="active-trail dropdown-toggle active" data-toggle="dropdown" data-target="#">MITB Tracks <span class="caret"></span></a><ul class="dropdown-menu"><li class="first collapsed"><a href="/master-it-business/analytics-track/curriculum" class="active">Analytics Track</a></li>
# <li class="collapsed"><a href="/master-it-business/artificial-inteligence-track/curriculum">Artificial Intelligence Track</a></li>
# <li class="collapsed"><a href="/master-it-business/digital-transformation-track/curriculum" class="menu-node-unpublished menu-node-unpublished">Digital Transformation Track</a></li>
# <li class="collapsed"><a href="/master-it-business/financial-technology-and-analytics-track/curriculum">Financial Technology &amp; Analytics Track</a></li>
# <li class="last leaf"><a href="/master-it-business/mitb-graduate-pathways">MITB Graduate Pathways</a></li>
# </ul></li>
# <li class="expanded dropdown"><a href="/master-it-business/academic-experience" class="dropdown-toggle" data-toggle="dropdown" data-target="#">Academic Experience <span class="caret"></span></a><ul class="dropdown-menu"><li class="first leaf"><a href="/master-it-business/academic-experience/our-students">Our Students</a></li>
# <li class="leaf"><a href="/master-it-business/academic-experience/our-alumni">Our Alumni</a></li>
# <li class="collapsed"><a href="/master-it-business/academic-experience/faculty-staff">Faculty &amp; Staff</a></li>
# <li class="leaf"><a href="/master-it-business/academic-experience/beyond-classroom">Beyond the Classroom</a></li>
# <li class="leaf"><a href="/master-it-business/internships">Internships</a></li>
# <li class="leaf"><a href="/master-it-business/capstone-project" class="menu-node-unpublished menu-node-unpublished">Capstone Project</a></li>
# <li class="last leaf"><a href="/master-it-business/deans-list" class="menu-node-unpublished menu-node-unpublished">Dean&#039;s List</a></li>
# </ul></li>
# <li class="expanded dropdown"><a href="/master-it-business/admissions/entry-requirements" class="dropdown-toggle" data-toggle="dropdown" data-target="#">Admissions <span class="caret"></span></a><ul class="dropdown-menu"><li class="first leaf"><a href="/master-it-business/admissions/entry-requirements">Entry Requirements</a></li>
# <li class="leaf"><a href="/master-it-business/admission-main/fees">Tuition Fees</a></li>
# <li class="last leaf"><a href="/master-it-business/scholarship">Scholarships &amp; Discounts</a></li>
# </ul></li>
# <li class="expanded dropdown"><a href="/master-it-business/faqs/curriculum-enrolment" class="menu-node-unpublished menu-node-unpublished menu-node-unpublished dropdown-toggle" data-toggle="dropdown" data-target="#">FAQs <span class="caret"></span></a><ul class="dropdown-menu"><li class="first leaf"><a href="/master-it-business/faqs/curriculum-enrolment">Curriculum &amp; Enrolment</a></li>
# <li class="leaf"><a href="/master-it-business/faqs/admission-eligibility">Admission &amp; Eligibility</a></li>
# <li class="leaf"><a href="/master-it-business/faqs/fees-financial-assistance">Fees &amp; Financial Assistance</a></li>
# <li class="leaf"><a href="/master-it-business/faqs/career-support">Career Support</a></li>
# <li class="last leaf"><a href="/master-it-business/faqs/immigration-matters-accommodation">Immigration Matters &amp; Accommodation</a></li>
# </ul></li>
# <li class="leaf"><a href="/master-it-business/download-brochure-mitb">Download Brochure</a></li>
# <li class="expanded dropdown"><a href="/master-it-business/news-events/highlights" class="dropdown-toggle" data-toggle="dropdown" data-target="#">News & Events <span class="caret"></span></a><ul class="dropdown-menu"><li class="first leaf"><a href="/master-it-business/news-events/current-events">Current Events</a></li>
# <li class="leaf"><a href="/master-it-business/news-events/past-events">Past Events</a></li>
# <li class="last leaf"><a href="/master-it-business/news-events/highlights">Highlights</a></li>
# </ul></li>
# <li class="last leaf"><a href="/master-it-business/apply-now">Apply Now</a></li>
# </ul> </div>
# </div></div>
#  <!-- /.region -->
#                                               </div>
#                     </div>
#                 </div>
#               </div>
#             </nav>
#             </div>
#         </div>
#     </div><!--header two block nav style-->
#     <!--end pce-->
#
#   </div> <!--end header for block nav style-->
#   <div class="mobile-subheader hidden-md hidden-lg">
#             <div class="container">
#               <h3 class="subheader subheader-2  pg-subhead"></h3>
#             </div>
#           </div>
#
#     <!--end inline nav check-->
#    <!--end $main_menu and search box -->
#
# <div id="main" class="clearfix main row" role="main">
#   <div id="main-header" class="main-header col-md-9">
#     <div class="container">
#             <div class="breadcrumb"> <h2 class="element-invisible">You are here</h2><div class="breadcrumb"><a href="/">Home</a></div> </div>
#                   <div class="page-title">
#         <h2 class="title" id="page-title"> Analytics Track </h2>
#       </div>
#           </div>
#   </div>
#   <div class="container">
#     <div id="main-content" class="main-content">             <div id="content" class="content col-md-9">
#         <div id="content-wrapper" class="content-wrapper">
#           <div id="content-head" class="content-head">
#             <div class="clearfix clear-row">                                                                                   </div>
#           </div>
#                               <div id="content-body" class="content-body"> <div class="region region-content clearfix">
#   <div id="block-system-main" class="clearfix block block-system">       <div class="content"> <article id="node-30326" class="node node-page clearfix" about="/master-it-business/analytics-track/curriculum" typeof="foaf:Document">      <span property="dc:title" content="Analytics Track" class="rdf-meta element-hidden"></span>    <div class="content">
#     <div class="field field-name-body field-type-text-with-summary field-label-hidden"><div class="field-items"><div class="field-item even" property="content:encoded"><style type="text/css">
#     .modal {
#         z-index: 99999;
#     }
#     .modal-title {
#         float: left;
#         margin: 0;
#         padding: 0;
#         margin-right: 15px;
#     }
#     .table-clear,
#     .table-clear thead tr td,
#     .table-clear tbody tr td {
#         border: none !important;
#     }
#     .intro-table{
#         width: 100%;
#         margin: 0; padding: 0;
#         border:none;
#     }
#     .intro-table tbody{
#         border: none;
#         }
#     .intro-table tr td{
#         border: none;
#     }
#     .intro-table-content{
#         width: 50%;
#         padding-right: 15px;
#     }
#     .intro-table-pic{
#         width: 50%; vertical-align: middle;
#     }
#     .intro-table-pic img{
#         display: inline-block;
#     }
#     .pane-curriculum-structure #curriculum-accordion a.accordion-toggle:hover, .pane-curriculum-structure #curriculum-accordion a.accordion-toggle:focus {
#         background-color: #c69200 !important;
#     }
#     .pane-curriculum-structure #curriculum-accordion a.accordion-toggle {
#         background-color: #c69200 !important;
#     }
#
#     .fulltime-box-wrapper h3, .fulltime-box-wrapper h4, .parttime-box-wrapper h3, .parttime-box-wrapper h4 {
#         font-family: "proxima-nova-extra-condensed",sans-serif;
#         font-weight: bold;
#         text-transform: uppercase; color:#fff}
#     .fulltime-box-wrapper {
#         float: left;
#         width: 50%;
#     }
#     .fulltime-box-inner {
#         margin: 1px;
#         padding: 15px;
#         min-height: 150px;
#         background: #363636;
#         text-align: center;
#         color: #fff;
#     }
#     .parttime-box-wrapper {
#         float: left;
#         width: 50%;
#     }
#     .parttime-box-inner {
#         margin: 1px;
#         padding: 15px;
#         min-height: 150px;
#         background: #363636;
#         text-align: center;
#         color: #fff;
#     }
#     .item-wrapper-a {
#         min-height: 185px;
#     }
#     .custom-list li{
#         margin-bottom: 5px;
#     }
#     @media screen and (max-width: 900px) {
#         .intro-table-content,
#         .intro-table-pic{
#             display: block;
#             width: 100%; padding-bottom: 15px;
#         }
#     }
# </style>
# <div style="max-width: 862px;">
# <div>
#     <h2 style="margin-top: 0; padding-top: 0;"><strong>Analytics Track</strong></h2>
#     <hr />
#     <table cellpadding="0" cellspacing="0" class="intro-table">
#         <tr>
#             <td valign="top" class="intro-table-content">
#                 <p>In a data-driven economy, the ability to make better decisions, create value and develop a sustained competitive advantage using data analytics techniques, is imperative. The SMU MITB Analytics (AT) track is Asia's first professional masters programme to meet the ever increasing demand for well-trained data analytics professionals. Co-designed by leading global and regional sector firms from hospitality, tourism, supply chain, retail, healthcare, public sector, banking and telecommunications, it promises a systematic understanding and application of the end-to-end data analytics processes to answer key business questions. With businesses keen to leverage the power of data analytics, it is no longer a choice, but a necessity for business survival and growth.</p>
#             </td>
#             <td valign="middle" class="intro-table-pic">
#                 <img alt="" class="img-responsive" src="//scis.smu.edu.sg/sites/sis.smu.edu.sg/files/sis/programmes/MITB/images/new-site-2018/at-banner.png" />
#             </td>
#         </tr>
#     </table>
# </div>
# <div class="pane-curriculum-structure">
#     <div class="accordion" id="curriculum-accordion">
#         <!--end group-->
#         <div class="accordion-group">
#             <div class="accordion-heading"><a aria-controls="faq1" aria-expanded="false" class="accordion-toggle collapsed" data-parent="#curriculum-accordion" data-toggle="collapse" href="#study" role="button"><strong>Full Time / Part Time study</strong></a></div>
#             <div aria-labelledby="study" class="panel-collapse collapse" id="study" role="tabpanel">
#                 <div class="accordion-inner">
#                     <!--content-->
#                     <p>The Master of IT in Business (AT) is an intensive programme with 2 options for completion:</p>
#                     <div class="box-wrapper">
#                         <div class="fulltime-box-wrapper">
#                             <div class="fulltime-box-inner matchheight-item" style="height: 150px;">
#                                 <h3>Full-time candidature :</h3>
#                                 <h4>A MINIMUM OF 1 YEAR TO A MAXIMUM OF 2 YEARS</h4>
#                             </div>
#                         </div>
#                         <div class="parttime-box-wrapper">
#                             <div class="fulltime-box-inner matchheight-item" style="height: 150px;">
#                                 <h3>Part-time candidature :</h3>
#                                 <h4>A minimum of 2 years to a maximum of 4 years</h4>
#                             </div>
#                         </div>
#                         <div class="clearfix">&nbsp;</div>
#                     </div>
#                     <p>Students can switch between these 2 modes of candidature at any time, but the change can only be made once.</p>
#                     <!--end content-->
#                 </div>
#             </div>
#         </div>
#         <!--end group-->
#         <div class="accordion-group">
#             <div class="accordion-heading"><a aria-controls="part-time" aria-expanded="false" class="accordion-toggle collapsed" data-parent="#curriculum-accordion" data-toggle="collapse" href="#calendar" role="button"><strong>Academic Calendar</strong></a></div>
#             <div aria-labelledby="calendar" class="panel-collapse collapse" id="calendar" role="tabpanel">
#                 <div class="accordion-inner">
#                     <!--content-->
#                     <p>The MITB programme runs its academic year based on that of the Singapore Management University, which operates on 3 regular terms comprising 10 study weeks, and 2 special terms of 5 study weeks. Some courses may include an additional week to administer examinations.</p>
#                     <!--end content-->
#                 </div>
#             </div>
#         </div>
#         <!--end group-->
#         <div class="accordion-group">
#             <div class="accordion-heading"><a aria-controls="gred-req" aria-expanded="false" class="accordion-toggle collapsed" data-parent="#curriculum-accordion" data-toggle="collapse" href="#delivery" role="button"><strong>Course Delivery</strong></a></div>
#             <div aria-labelledby="delivery" class="panel-collapse collapse" id="delivery" role="tabpanel">
#                 <div class="accordion-inner">
#                     <!--content-->
#                     <p>MITB class sessions are 3 hours long, and are conducted in a highly interactive, seminar-styled manner. Class sessions combine lectures with discussions, hands-on lab sessions, problem-solving practice classes, and group work. Through our pedagogy, students have the opportunity to interact closely with faculty, full-time professional hires (instructors) and student teaching assistants. In addition, students also meet with industry experts who share their experiences and perspectives through regular seminars organised by the MITB (AT) programme.</p>
#                     <!--end content-->
#                 </div>
#             </div>
#         </div>
#         <!--end group-->
#         <div class="accordion-group">
#             <div class="accordion-heading"><a aria-controls="core-mod" aria-expanded="false" class="accordion-toggle collapsed" data-parent="#curriculum-accordion" data-toggle="collapse" href="#timetable" role="button"><strong>Timetable</strong></a></div>
#             <div aria-labelledby="timetable" class="panel-collapse collapse" id="timetable" role="tabpanel">
#                 <div class="accordion-inner">
#                     <!--content-->
#                     <p>All classes are held either on weekday evenings from 7pm onwards, Saturday mornings from 8.15am onwards, or Saturday afternoons from 12pm onwards. These timings have been chosen to accommodate the schedules of part-time students who are working, and full-time students who might be engaged with industry attachments.</p>
#                     <!--end content-->
#                 </div>
#             </div>
#         </div>
#         <!--end group-->
#         <div class="accordion-group">
#                 <div class="accordion-heading">
#                     <a aria-controls="electives" aria-expanded="false" class="accordion-toggle collapsed" data-parent="#curriculum-accordion" data-toggle="collapse" href="#grad-req" role="button">
#                         <strong>Curriculum / Graduation Requirements</strong>
#                     </a>
#                 </div>
#                 <div aria-labelledby="grad-req" class="panel-collapse collapse" id="grad-req" role="tabpanel">
#                     <div class="accordion-inner">
#                         <!--------------------------------------------  match height -------------------------------------------->
#                         <script>
#                             (function (c) {
#                                 var n = -1,
#                                     f = -1,
#                                     g = function (a) {
#                                         return parseFloat(a) || 0;
#                                     },
#                                     r = function (a) {
#                                         var b = null,
#                                             d = [];
#                                         c(a).each(function () {
#                                             var a = c(this),
#                                                 k = a.offset().top - g(a.css("margin-top")),
#                                                 l = 0 < d.length ? d[d.length - 1] : null;
#                                             null === l ? d.push(a) : 1 >= Math.floor(Math.abs(b - k)) ? (d[d.length - 1] = l.add(a)) : d.push(a);
#                                             b = k;
#                                         });
#                                         return d;
#                                     },
#                                     p = function (a) {
#                                         var b = { byRow: !0, property: "height", target: null, remove: !1 };
#                                         if ("object" === typeof a) return c.extend(b, a);
#                                         "boolean" === typeof a ? (b.byRow = a) : "remove" === a && (b.remove = !0);
#                                         return b;
#                                     },
#                                     b = (c.fn.matchHeight = function (a) {
#                                         a = p(a);
#                                         if (a.remove) {
#                                             var e = this;
#                                             this.css(a.property, "");
#                                             c.each(b._groups, function (a, b) {
#                                                 b.elements = b.elements.not(e);
#                                             });
#                                             return this;
#                                         }
#                                         if (1 >= this.length && !a.target) return this;
#                                         b._groups.push({ elements: this, options: a });
#                                         b._apply(this, a);
#                                         return this;
#                                     });
#                                 b._groups = [];
#                                 b._throttle = 80;
#                                 b._maintainScroll = !1;
#                                 b._beforeUpdate = null;
#                                 b._afterUpdate = null;
#                                 b._apply = function (a, e) {
#                                     var d = p(e),
#                                         h = c(a),
#                                         k = [h],
#                                         l = c(window).scrollTop(),
#                                         f = c("html").outerHeight(!0),
#                                         m = h.parents().filter(":hidden");
#                                     m.each(function () {
#                                         var a = c(this);
#                                         a.data("style-cache", a.attr("style"));
#                                     });
#                                     m.css("display", "block");
#                                     d.byRow &&
#                                         !d.target &&
#                                         (h.each(function () {
#                                             var a = c(this),
#                                                 b = a.css("display");
#                                             "inline-block" !== b && "inline-flex" !== b && (b = "block");
#                                             a.data("style-cache", a.attr("style"));
#                                             a.css({ display: b, "padding-top": "0", "padding-bottom": "0", "margin-top": "0", "margin-bottom": "0", "border-top-width": "0", "border-bottom-width": "0", height: "100px" });
#                                         }),
#                                         (k = r(h)),
#                                         h.each(function () {
#                                             var a = c(this);
#                                             a.attr("style", a.data("style-cache") || "");
#                                         }));
#                                     c.each(k, function (a, b) {
#                                         var e = c(b),
#                                             f = 0;
#                                         if (d.target) f = d.target.outerHeight(!1);
#                                         else {
#                                             if (d.byRow && 1 >= e.length) {
#                                                 e.css(d.property, "");
#                                                 return;
#                                             }
#                                             e.each(function () {
#                                                 var a = c(this),
#                                                     b = a.css("display");
#                                                 "inline-block" !== b && "inline-flex" !== b && (b = "block");
#                                                 b = { display: b };
#                                                 b[d.property] = "";
#                                                 a.css(b);
#                                                 a.outerHeight(!1) > f && (f = a.outerHeight(!1));
#                                                 a.css("display", "");
#                                             });
#                                         }
#                                         e.each(function () {
#                                             var a = c(this),
#                                                 b = 0;
#                                             (d.target && a.is(d.target)) ||
#                                                 ("border-box" !== a.css("box-sizing") && ((b += g(a.css("border-top-width")) + g(a.css("border-bottom-width"))), (b += g(a.css("padding-top")) + g(a.css("padding-bottom")))),
#                                                 a.css(d.property, f - b + "px"));
#                                         });
#                                     });
#                                     m.each(function () {
#                                         var a = c(this);
#                                         a.attr("style", a.data("style-cache") || null);
#                                     });
#                                     b._maintainScroll && c(window).scrollTop((l / f) * c("html").outerHeight(!0));
#                                     return this;
#                                 };
#                                 b._applyDataApi = function () {
#                                     var a = {};
#                                     c("[data-match-height], [data-mh]").each(function () {
#                                         var b = c(this),
#                                             d = b.attr("data-mh") || b.attr("data-match-height");
#                                         a[d] = d in a ? a[d].add(b) : b;
#                                     });
#                                     c.each(a, function () {
#                                         this.matchHeight(!0);
#                                     });
#                                 };
#                                 var q = function (a) {
# ...
#                                                 <li>Develop communication, interpersonal and other critical soft skills required on the job </li>
#                                                 <li>Develop the work ethic and skills required for success in the internship</li>
#                                                 <li>Build a record of internship experiences</li>
#                                                 <li>Identify, document, and carry out performance objectives related to the internship</li>
#                                                 <li>Build professional relationships with internship supervisors, mentors, learning buddies, and other colleagues</li>
#                                                 <li>Prepare an engaging, organized, and logical presentation summarizing the internship</li>
#                                                 <li>Receive guidance and professional support throughout the internship</li>
#                                                 <li>Demonstrate independence, responsibility, and time management</li>
#                                             </ul>
#                                             <br />
#                                             <div class="video-modal-embed-wrapper">
#                                                 <div class="embed-responsive embed-responsive-16by9">
#                                                     <iframe class="embed-responsive-item" src="https://www.youtube.com/embed/tJs_eQOGDII?rel=0"></iframe>
#                                                 </div>
#                                             </div>
#                                         </div>
#                                     </div>
#                                 </div>
#                             </div>
#                             <!---------- //curicullum F1 ---------->
#                             <!---------- curicullum F2 ---------->
#                             <div aria-labelledby="myModalLabel" class="modal modal-wide fade" id="curriculum-F2" role="dialog">
#                                 <div class="modal-dialog">
#                                     <!-- Modal content-->
#                                     <div class="modal-content">
#                                         <div class="modal-header">
#                                             <h3 class="modal-title">Capstone Project</h3>
#                                             <button type="button" class="close" data-dismiss="modal" aria-label="Close">
#                                                 <span aria-hidden="true">&times;</span>
#                                             </button>
#                                             <div class="clearfix"></div>
#                                         </div>
#                                         <div class="modal-body">
#                                             <p align="justify">The MITB capstone project is an extensive, applied practice research project that is undertaken by students, supervised by SMU faculty members who have specific expertise and interest in the topic, and sometimes sponsored by external companies. It provides the students with an individualized learning experience to integrate and synthesize the skills, theories, and frameworks they have learnt in MITB programme. The project gives students an opportunity to delve in greater depth, into business challenges or topics in financial technologies, analytics, or AI field. Students shall identify a problem, develop the approach and methods needed to address the problem, and conduct the research and present the findings in both oral and written formats.</p>
#                                             <p align="justify">The capstone project experience aims to provide an authentic and practical interdisciplinary learning experience to take knowledge and theory they have learned in MITB and apply in a real-world setting. Upon completion of the capstone projects, students will be able to:</p>
#                                             <ul class="custom-list">
#                                                 <li>Gain theoretical and practice insight, including background and new information on topics within the students’ respective tracks</li>
#                                                 <li>Locate, collect and/or generate information and data relevant to the project</li>
#                                                 <li>Develop critical thinking through reading, research, and hands-on analysis of the problem and dataset</li>
#                                                 <li>Evaluate the strengths and weaknesses of current research findings, techniques and methodologies</li>
#                                                 <li>Select, defend, and apply methodological approaches to answer the project’s questions</li>
#                                                 <li>Analyze the information and data, synthesize them to generate new knowledge and understanding </li>
#                                                 <li>Manage the research project, monitor its progress, refine, and pivot the approaches as needed</li>
#                                                 <li>Contribute to the development of academic or professional skills, techniques, tools, practices, ideas, theories or approaches </li>
#                                                 <li>Describe the limitations of the work, the complexity of knowledge, and of the potential contributions of interpretations and methods</li>
#                                                 <li>Present the project and its findings in an engaging, organized, and logical manner, summarizing the entire capstone project</li>
#                                                 <li>Receive guidance and professional support throughout the project</li>
#                                                 <li>Demonstrate independence, responsibility and time management</li>
#                                             </ul>
#                                             <br />
#                                             <div class="video-modal-embed-wrapper">
#                                                 <div class="embed-responsive embed-responsive-16by9">
#                                                     <iframe class="embed-responsive-item" src="https://www.youtube.com/embed/tJs_eQOGDII?rel=0"></iframe>
#                                                 </div>
#                                             </div>
#                                         </div>
#                                     </div>
#                                 </div>
#                             </div>
#                             <!---------- //curicullum F2 ---------->
#                         </div>
#                         <!---------------------------------------- //curicullum modal wrapper ---------------------------------------->
#                     </div>
#                 </div>
#             </div>
#         <!--end group-->
#     </div>
# </div>
# </div>
# </div></div></div>    <p class="last-updated" align="right">Last updated on <strong>
#     05 May 2021  </strong>.</p>
#   </div>
#     </article>
#  </div>
# </div></div>
#  <!-- /.region -->
#   </div>
#                                       </div>
#         <!-- /#content-wrap -->
#       </div>
#       <!-- /#content -->
#             <div id="sidebar-second" class="sidebar col-md-3 site-sidebar-second"> <div class="region region-sidebar-second clearfix">
#   <div id="block-menu-block-6" class="clearfix block block-menu-block sidebar-right">       <div class="content"> <div class="menu-block-wrapper menu-block-6 menu-name-menu-menu-mitb-new- parent-mlid-0 menu-level-2">
#   <ul class="menu nav"><li class="first collapsed active menu-mlid-37276"><a href="/master-it-business/analytics-track/curriculum" class="active">Analytics Track</a></li>
# <li class="collapsed menu-mlid-37286"><a href="/master-it-business/artificial-inteligence-track/curriculum">Artificial Intelligence Track</a></li>
# <li class="collapsed menu-mlid-43106"><a href="/master-it-business/digital-transformation-track/curriculum" class="menu-node-unpublished menu-node-unpublished">Digital Transformation Track</a></li>
# <li class="collapsed menu-mlid-37281"><a href="/master-it-business/financial-technology-and-analytics-track/curriculum">Financial Technology &amp; Analytics Track</a></li>
# <li class="last leaf menu-mlid-42651"><a href="/master-it-business/mitb-graduate-pathways">MITB Graduate Pathways</a></li>
# </ul></div>
#  </div>
# </div></div>
#  <!-- /.region -->
# </div>
#
#       <!-- /#sidebar-second -->
#           </div>
#   </div>
# </div>
# <!-- /#main, /#main-wrapper -->
#
#
# <!--nextweb2 region-->
# <!--end nextweb 2 region-->
#
# <div id="footer" role="contentinfo">
# <div class="site-footer">
#
#     <div id="footer-bottom" class="footer-col3 row">
#       <div class="container">
#                 <div class="col-lg-4 col-md-4 col-sm-4 col-xs-12">
#           <div id="footer-col3-1" class="footer-col3"> <div class="region region-footer-col3-1 clearfix">
#   <div id="block-block-306" class="clearfix block block-block">       <div class="content"> <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="margin-top:20px;">
# 	<div class="col-lg-6 col-md-6 col-sm-12 col-xs-12">
# 		<h2 style="margin-top:0;" class="footer">Download the programme brochure</h2>
# 		<br />
# 		<a class="cta  cta-orange" href="//scis.smu.edu.sg/master-it-business/download-brochure-mitb" style="margin-bottom:1em;"  target="_blank">Download</a></div>
# 	<div class="col-lg-5 col-md-5 col-sm-12 col-xs-12"><a href="//scis.smu.edu.sg/master-it-business/download-brochure-mitb" target="_blank"><img src="//scis.smu.edu.sg/sites/sis.smu.edu.sg/files/MITB_Brochure_Cover_2021.jpg" style="width:139px;"/></a></div>
# </div>
# <p>&nbsp;</p>
# <p>&nbsp;</p> </div>
# </div></div>
#  <!-- /.region -->
#  </div>
#         </div>
#                         <div class="col-lg-4 col-md-4 col-sm-4 col-xs-12">
#           <div id="footer-col3-2" class="footer-col3"><div class="region region-footer-col3-2 clearfix">
#   <div id="block-block-311" class="clearfix block block-block text-center">       <div class="content"> <div class="block block-panels-mini sticky-footer" id="block-panels-mini-sticky-footer">&#13;
# <span class="removep">Take the next step:</span> <span><a class="btn btn-default btn-default-outline" href="//scis.smu.edu.sg/master-it-business/apply-now" target="_blank">Apply Now</a></span> &#13;
# <span><a class="btn btn-default btn-default-outline" href="//scis.smu.edu.sg/master-it-business/mailing-list-reg" target="_blank">Join Our Mailing List</a></span> &#13;
# <span><a class="btn btn-default btn-default-outline" href="//scis.smu.edu.sg/master-it-business/deposit-resume" target="_blank">Deposit Your Resume</a></span> &#13;
# <!--<span><a class="btn btn-default btn-default-outline" href="//scis.smu.edu.sg/master-it-business/xperience-mitb" target="_blank">Xperience MITB</a></span>&#13;-->
#  <span><a class="btn btn-default btn-default-outline" href="//scis.smu.edu.sg/master-it-business/news-events/current-events" target="_blank">Attend an Info Session</a></span>&#13;
# <span><a class="btn btn-default btn-default-outline removep" href="//scis.smu.edu.sg/master-it-business/download-employment-report-mitb" target="_blank">Download Employment Report</a></span>&#13;
# </div>&#13;
#  </div>
# </div></div>
#  <!-- /.region -->
#  </div>
#         </div>
#                         <div class="col-lg-4 col-md-4 col-sm-4 col-xs-12">
#           <div id="footer-col3-3" class="footer-col3">
#             <div class="footer-search">
#               <h2 class="block-title">Looking for something?</h2>
#             <form name="cse" id="searchbox" action="https://www.smu.edu.sg/search">
#                       <div class="input-group">
#                         <input name="query" type="text" class="form-control pull-right" placeholder="Search SMU..." />
#                         <div class="input-group-btn">
#                           <button type="submit" class="btn btn-default"
#                                  tabindex="-1" style="border-radius:4px; margin-left:5px; background-image:linear-gradient(to bottom, #e0e0e0 0px, #e0e0e0 100%);" value="Search" name="sa"><span class="glyphicon glyphicon-search"></span> </button>
#                         </div>
#                       </div>
#             </form>
#           </div>
#
#
#           </div>
#         </div>
#               </div>
#     </div>
# <div class="row">
#             <div class="container">
#                 <div class="col-md-12  content-col3-footer-bottom fine-footer">
#     <div id="copyright" class="pull-left">
#       <div class="footer-menu">
#       <a href="https://www.smu.edu.sg/terms-use" class="href"> Terms of Use</a> |
#       <a href="https://www.smu.edu.sg/privacy-statement" class="href">Privacy Statement </a> |
#       <a href="https://www.smu.edu.sg/personal-data-protection" class="href">Personal Data Statement </a> |
#       <a href="https://www.smu.edu.sg/form/contact-dpo" class="href">Contact Data Protection Officer </a>
#       </div>
#       <div class="footer-copyright">&copy; Copyright 2021 Singapore Management University. All Rights Reserved</div>
#     </div>
#     <div id="social-menu" class="pull-right">
#
#       <ul class="social-menu">
#
#           <li class="facebook"><a target="_blank" class="smu-social-channels facebook" title="SMU on Facebook" href="http://facebook.com/sgsmu"><i class="fa fab fa-facebook-square"></i><span class="menu-item">Facebook</span></a></li>
#
#            <li class="instragram"><a target="_blank" class="smu-social-channels instragram" href="https://www.instagram.com/sgsmu"><i class="fa fab fa-instagram"></i><span class="menu-item">Instagram</span></a></li>
#            <li class="twitter"><a target="_blank" class="smu-social-channels twitter" title="SMU (@sgsmu) on Twitter" href="http://twitter.com/sgsmu"><i class="fa fab fa-twitter-square"></i><span class="menu-item">Twitter</span></a></li>
#
#            <li class="linkedin"><a target="_blank" class="smu-social-channels linkedin" title="SMU on LinkedIn" href="http://www.linkedin.com/company/singapore-management-university/"><i class="fa fab fa-linkedin"></i><span class="menu-item">LinkedIn</span></a></li>
#           <li class="youtube"><a target="_blank" class="smu-social-channels youtube" title="SMU on YouTube" href="http://www.youtube.com/smutubesg"><i class="fa fab fa-youtube-square"></i><span class="menu-item">YouTube</span></a></li>
#           <li class="soundcloud"><a target="_blank" class="smu-social-channels soundcloud" href="http://soundcloud.com/sgsmu"><i class="fa fab fa-soundcloud"></i><span class="menu-item">SoundCloud</span></a></li>
#
#           <!-- li class="itunesu"><a target="_blank" class="smu-social-channels itunesu" href="http://itunes.smu.edu.sg/"><i class="fa fa-graduation-cap"></i><span class="menu-item">ITunes U</span></a></li -->
#
#           <!--<li class="rss"><a target="_blank" class="smu-social-channels rss" href="http://www.smu.edu.sg/rss"><i class="fa fa-rss-square"></i><span class="menu-item">Rss</span></a></li>-->
#           <li class="smublog"><a target="_blank" class="smu-social-channels smublog" href="http://blog.smu.edu.sg/"><i class="fa fa-pencil-square"></i><span class="menu-item">SMU Blog</span></a></li>
#           <!--<li class="smumobile"><a target="_blank" class="smu-social-channels smumobile" href="http://m.smu.edu.sg/"><i class="fa fab fa-apple"></i><span class="menu-item">SMU Mobile</span></a></li>
#            <li class="smumobile"><a target="_blank" class="smu-social-channels smumobile" href="http://m.smu.edu.sg/"><i class="fa fab fa-android"></i><span class="menu-item">SMU Mobile</span></a></li>-->
#            <li class="smumobile"><a target="_blank" class="smu-social-channels smutelegram" href="https://t.me/sgsmu"><i class="fa fab fa-telegram"></i><span class="menu-item">Telegram</span></a></li>
#         </ul>
#     </div>
#             </div>
#         </div>
# </div>
#   </div>
# </div>
#
# <!-- /#footer -->
#
#
#
#   </body>
#
# </html>

# %%
soup = BeautifulSoup(r.text, "html5lib")
print(soup.get_text())
# Out:
#
#
#
#
#
#
#
#
#
#
#
#     Analytics Track | School of Computing and Information Systems (SMU)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!--//--><![CDATA[//><!--
# try{Typekit.load();}catch(e){}
# //--><!]]>
#
#
#
#
#
#
#
#
#
#
#
# <!--//--><![CDATA[//><!--
# jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"","ajaxPageState":{"theme":"smu_pg","theme_token":"7UCl8c1CYvAWG2TZNt-fpoRLmsOXtZEWl4-m8TIHPfQ","js":{"sites\/all\/libraries\/respondjs\/respond.min.js":1,"sites\/all\/modules\/jquery_update\/replace\/jquery\/1.9\/jquery.min.js":1,"misc\/jquery-extend-3.4.0.js":1,"misc\/jquery-html-prefilter-3.5.0-backport.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"sites\/all\/modules\/jquery_update\/replace\/ui\/ui\/minified\/jquery.ui.effect.min.js":1,"\/sites\/all\/libraries\/angular\/angular.js":1,"sites\/all\/modules\/back_to_top\/js\/back_to_top.js":1,"sites\/all\/libraries\/colorbox\/jquery.colorbox-min.js":1,"sites\/all\/modules\/colorbox\/js\/colorbox.js":1,"sites\/all\/modules\/colorbox\/styles\/default\/colorbox_style.js":1,"sites\/all\/modules\/colorbox\/js\/colorbox_load.js":1,"sites\/all\/modules\/smu\/smusearch\/smusearch.js":1,"sites\/all\/themes\/smubase\/packages\/bootstrap\/js\/bootstrap.min.js":1,"\/\/use.typekit.com\/uhs0req.js":1,"0":1,"\/sites\/all\/libraries\/jquery-touchswipe\/jquery.touchSwipe.min.js":1,"\/sites\/all\/libraries\/jquery.easing\/jquery.easing.1.3.js":1,"\/sites\/all\/libraries\/jquery-loading-overlay\/dist\/loading-overlay.min.js":1,"\/sites\/all\/libraries\/responsive-tab\/responsive-tabs.js":1,"sites\/all\/themes\/open_framework\/js\/open_framework.js":1,"sites\/all\/themes\/open_framework\/js\/jquery.placeholder.min.js":1,"sites\/all\/themes\/smubase_rev\/js\/js.js":1,"sites\/all\/themes\/smubase_rev\/js\/mobilemenu.js":1,"sites\/all\/themes\/smu_pg\/js\/script.js":1},"css":{"modules\/system\/system.base.css":1,"modules\/system\/system.menus.css":1,"modules\/system\/system.messages.css":1,"modules\/system\/system.theme.css":1,"modules\/aggregator\/aggregator.css":1,"sites\/all\/modules\/date\/date_api\/date.css":1,"sites\/all\/modules\/date\/date_popup\/themes\/datepicker.1.7.css":1,"modules\/field\/theme\/field.css":1,"modules\/node\/node.css":1,"sites\/all\/modules\/siteimprove\/css\/siteimprove.css":1,"modules\/user\/user.css":1,"sites\/all\/modules\/views\/css\/views.css":1,"sites\/all\/modules\/back_to_top\/css\/back_to_top.css":1,"sites\/all\/modules\/colorbox\/styles\/default\/colorbox_style.css":1,"sites\/all\/modules\/ctools\/css\/ctools.css":1,"sites\/all\/modules\/facebook_pull\/facebook_pull.css":1,"sites\/all\/themes\/smubase\/packages\/bootstrap\/css\/bootstrap.min.css":1,"sites\/all\/themes\/smubase\/packages\/bootstrap\/css\/bootstrap-theme.min.css":1,"sites\/all\/themes\/smubase\/packages\/font-awesome-4.1.0\/css\/font-awesome.min.css":1,"sites\/all\/themes\/open_framework\/css\/open_framework.css":1,"sites\/all\/themes\/smubase_rev\/css\/global.css":1,"sites\/all\/themes\/smubase_rev\/css\/footer.css":1,"sites\/all\/themes\/smubase_rev\/css\/responsive.css":1,"sites\/all\/themes\/smubase_rev\/css\/feature.css":1,"sites\/all\/themes\/smu_pg\/stylesheets\/styles.css":1,"sites\/all\/themes\/smu_pg\/stylesheets\/custom.css":1,"sites\/all\/themes\/open_framework\/css\/open_framework_print.css":1,"sites\/all\/themes\/smubase_rev\/css\/print.css":1}},"colorbox":{"opacity":"0.85","current":"{current} of {total}","previous":"\u00ab Prev","next":"Next \u00bb","close":"Close","maxWidth":"98%","maxHeight":"98%","fixed":true,"mobiledetect":true,"mobiledevicewidth":"480px"},"better_exposed_filters":{"views":{"information_sessions":{"displays":{"block_2":{"filters":[]}}}}},"back_to_top":{"back_to_top_button_trigger":100,"back_to_top_button_text":"Back to top","#attached":{"library":[["system","ui"]]}}});
# //--><!]]>
#
#
#
#
#
#
#
#
#       (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#       new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#       j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#       '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#       })(window,document,'script','dataLayer','GTM-PPDXSR');
#
#     Skip to content
# Skip to navigation
#
#
#
#
#
#
#
#
#
#
#
#
#           #announcement {     background: crimson; color:#fff; } #announcement .announcement {     padding: 5px 15px; } #announcement p {     padding: 0;     margin: 0; } #announcement a { color:#fff; } #announcement  .fas.fa-external-link-alt {     margin-left: 5px;     font-size: 10px; }
#
#
#             Advisories and updates on 2019 Novel Coronavirus (COVID-19)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   Connect
#
#
#
#
#
#             Faculty/Staff Email
#             Student Email
#             iNet Intranet
#             OASIS Intranet
#
#
#
#
#             eLearn
#             SMU Extranet
#             OnTrac II
#             Google Apps
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                           Close
#
#
#
#
#
#
# #smusearch_dropdown li{ padding-left:10px;}
#
#
#
#
#
#
#         Toggle Dropdown
#
#
#
#           This Site
#
#
#
#           SMU Main Site
#
#
#
#
#
#
#
#
#
#                         Close
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# #smusearch_dropdown li{ padding-left:10px;}
#
#
#
#
#
#
#         Toggle Dropdown
#
#
#
#           This Site
#
#
#
#           SMU Main Site
#
#
#
#
#
#
#
#
#
#                         Close
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                   Toggle navigation
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#        Menu: MITB (New)
#        Master of IT in Business
# About MITB Why SMU MITB?
# Career Services
# Graduate Employability
# University Partners
# Thought Leadership
# MITB Vantage
# ResearchUnified Banking Process Framework
# SMU Teaching Bank
#
#
# MITB Tracks Analytics Track
# Artificial Intelligence Track
# Digital Transformation Track
# Financial Technology & Analytics Track
# MITB Graduate Pathways
#
# Academic Experience Our Students
# Our Alumni
# Faculty & Staff
# Beyond the Classroom
# Internships
# Capstone Project
# Dean's List
#
# Admissions Entry Requirements
# Tuition Fees
# Scholarships & Discounts
#
# FAQs Curriculum & Enrolment
# Admission & Eligibility
# Fees & Financial Assistance
# Career Support
# Immigration Matters & Accommodation
#
# Download Brochure
# News & Events Current Events
# Past Events
# Highlights
#
# Apply Now
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#              You are hereHome
#
#          Analytics Track
#
#
#
#
#
#
#
#
#
#
#
#
#     .modal {
#         z-index: 99999;
#     }
#     .modal-title {
#         float: left;
#         margin: 0;
#         padding: 0;
#         margin-right: 15px;
#     }
#     .table-clear,
#     .table-clear thead tr td,
#     .table-clear tbody tr td {
#         border: none !important;
#     }
#     .intro-table{
#         width: 100%;
#         margin: 0; padding: 0;
#         border:none;
#     }
#     .intro-table tbody{
#         border: none;
#         }
#     .intro-table tr td{
#         border: none;
#     }
#     .intro-table-content{
#         width: 50%;
#         padding-right: 15px;
#     }
#     .intro-table-pic{
#         width: 50%; vertical-align: middle;
#     }
#     .intro-table-pic img{
#         display: inline-block;
#     }
#     .pane-curriculum-structure #curriculum-accordion a.accordion-toggle:hover, .pane-curriculum-structure #curriculum-accordion a.accordion-toggle:focus {
#         background-color: #c69200 !important;
#     }
#     .pane-curriculum-structure #curriculum-accordion a.accordion-toggle {
#         background-color: #c69200 !important;
#     }
#
#     .fulltime-box-wrapper h3, .fulltime-box-wrapper h4, .parttime-box-wrapper h3, .parttime-box-wrapper h4 {
#         font-family: "proxima-nova-extra-condensed",sans-serif;
#         font-weight: bold;
#         text-transform: uppercase; color:#fff}
#     .fulltime-box-wrapper {
#         float: left;
#         width: 50%;
#     }
#     .fulltime-box-inner {
#         margin: 1px;
#         padding: 15px;
#         min-height: 150px;
#         background: #363636;
#         text-align: center;
#         color: #fff;
#     }
#     .parttime-box-wrapper {
#         float: left;
#         width: 50%;
#     }
#     .parttime-box-inner {
#         margin: 1px;
#         padding: 15px;
#         min-height: 150px;
#         background: #363636;
#         text-align: center;
#         color: #fff;
#     }
#     .item-wrapper-a {
#         min-height: 185px;
#     }
#     .custom-list li{
#         margin-bottom: 5px;
#     }
#     @media screen and (max-width: 900px) {
#         .intro-table-content,
#         .intro-table-pic{
#             display: block;
#             width: 100%; padding-bottom: 15px;
#         }
#     }
#
#
#
#     Analytics Track
#
#
#
#
#                 In a data-driven economy, the ability to make better decisions, create value and develop a sustained competitive advantage using data analytics techniques, is imperative. The SMU MITB Analytics (AT) track is Asia's first professional masters programme to meet the ever increasing demand for well-trained data analytics professionals. Co-designed by leading global and regional sector firms from hospitality, tourism, supply chain, retail, healthcare, public sector, banking and telecommunications, it promises a systematic understanding and application of the end-to-end data analytics processes to answer key business questions. With businesses keen to leverage the power of data analytics, it is no longer a choice, but a necessity for business survival and growth.
#
#
#
#
#
#
#
#
#
#
#
#             Full Time / Part Time study
#
#
#
#                     The Master of IT in Business (AT) is an intensive programme with 2 options for completion:
#
#
#
#                                 Full-time candidature :
#                                 A MINIMUM OF 1 YEAR TO A MAXIMUM OF 2 YEARS
#
#
#
#
#                                 Part-time candidature :
#                                 A minimum of 2 years to a maximum of 4 years
#
#
#
#
#                     Students can switch between these 2 modes of candidature at any time, but the change can only be made once.
#
#
#
#
#
#
#             Academic Calendar
#
#
#
#                     The MITB programme runs its academic year based on that of the Singapore Management University, which operates on 3 regular terms comprising 10 study weeks, and 2 special terms of 5 study weeks. Some courses may include an additional week to administer examinations.
#
#
#
#
#
#
#             Course Delivery
#
#
#
#                     MITB class sessions are 3 hours long, and are conducted in a highly interactive, seminar-styled manner. Class sessions combine lectures with discussions, hands-on lab sessions, problem-solving practice classes, and group work. Through our pedagogy, students have the opportunity to interact closely with faculty, full-time professional hires (instructors) and student teaching assistants. In addition, students also meet with industry experts who share their experiences and perspectives through regular seminars organised by the MITB (AT) programme.
#
#
#
#
#
#
#             Timetable
#
#
#
#                     All classes are held either on weekday evenings from 7pm onwards, Saturday mornings from 8.15am onwards, or Saturday afternoons from 12pm onwards. These timings have been chosen to accommodate the schedules of part-time students who are working, and full-time students who might be engaged with industry attachments.
#
#
#
#
#
#
#
#
#                         Curriculum / Graduation Requirements
#
#
#
#
#
#
#                             (function (c) {
#                                 var n = -1,
#                                     f = -1,
#                                     g = function (a) {
#                                         return parseFloat(a) || 0;
#                                     },
#                                     r = function (a) {
#                                         var b = null,
#                                             d = [];
#                                         c(a).each(function () {
#                                             var a = c(this),
#                                                 k = a.offset().top - g(a.css("margin-top")),
#                                                 l = 0 < d.length ? d[d.length - 1] : null;
#                                             null === l ? d.push(a) : 1 >= Math.floor(Math.abs(b - k)) ? (d[d.length - 1] = l.add(a)) : d.push(a);
#                                             b = k;
#                                         });
#                                         return d;
#                                     },
#                                     p = function (a) {
#                                         var b = { byRow: !0, property: "height", target: null, remove: !1 };
#                                         if ("object" === typeof a) return c.extend(b, a);
#                                         "boolean" === typeof a ? (b.byRow = a) : "remove" === a && (b.remove = !0);
#                                         return b;
#                                     },
#                                     b = (c.fn.matchHeight = function (a) {
#                                         a = p(a);
#                                         if (a.remove) {
#                                             var e = this;
#                                             this.css(a.property, "");
#                                             c.each(b._groups, function (a, b) {
#                                                 b.elements = b.elements.not(e);
#                                             });
#                                             return this;
#                                         }
#                                         if (1 >= this.length && !a.target) return this;
#                                         b._groups.push({ elements: this, options: a });
#                                         b._apply(this, a);
#                                         return this;
#                                     });
#                                 b._groups = [];
#                                 b._throttle = 80;
#                                 b._maintainScroll = !1;
#                                 b._beforeUpdate = null;
#                                 b._afterUpdate = null;
#                                 b._apply = function (a, e) {
#                                     var d = p(e),
#                                         h = c(a),
#                                         k = [h],
#                                         l = c(window).scrollTop(),
#                                         f = c("html").outerHeight(!0),
#                                         m = h.parents().filter(":hidden");
#                                     m.each(function () {
#                                         var a = c(this);
#                                         a.data("style-cache", a.attr("style"));
#                                     });
#                                     m.css("display", "block");
#                                     d.byRow &&
#                                         !d.target &&
#                                         (h.each(function () {
#                                             var a = c(this),
#                                                 b = a.css("display");
#                                             "inline-block" !== b && "inline-flex" !== b && (b = "block");
#                                             a.data("style-cache", a.attr("style"));
#                                             a.css({ display: b, "padding-top": "0", "padding-bottom": "0", "margin-top": "0", "margin-bottom": "0", "border-top-width": "0", "border-bottom-width": "0", height: "100px" });
#                                         }),
#                                         (k = r(h)),
#                                         h.each(function () {
#                                             var a = c(this);
#                                             a.attr("style", a.data("style-cache") || "");
#                                         }));
#                                     c.each(k, function (a, b) {
#                                         var e = c(b),
#                                             f = 0;
#                                         if (d.target) f = d.target.outerHeight(!1);
#                                         else {
#                                             if (d.byRow && 1 >= e.length) {
#                                                 e.css(d.property, "");
#                                                 return;
#                                             }
#                                             e.each(function () {
#                                                 var a = c(this),
#                                                     b = a.css("display");
#                                                 "inline-block" !== b && "inline-flex" !== b && (b = "block");
#                                                 b = { display: b };
#                                                 b[d.property] = "";
#                                                 a.css(b);
#                                                 a.outerHeight(!1) > f && (f = a.outerHeight(!1));
#                                                 a.css("display", "");
#                                             });
#                                         }
#                                         e.each(function () {
#                                             var a = c(this),
#                                                 b = 0;
#                                             (d.target && a.is(d.target)) ||
#                                                 ("border-box" !== a.css("box-sizing") && ((b += g(a.css("border-top-width")) + g(a.css("border-bottom-width"))), (b += g(a.css("padding-top")) + g(a.css("padding-bottom")))),
#                                                 a.css(d.property, f - b + "px"));
#                                         });
#                                     });
#                                     m.each(function () {
#                                         var a = c(this);
#                                         a.attr("style", a.data("style-cache") || null);
#                                     });
#                                     b._maintainScroll && c(window).scrollTop((l / f) * c("html").outerHeight(!0));
#                                     return this;
#                                 };
#                                 b._applyDataApi = function () {
#                                     var a = {};
#                                     c("[data-match-height], [data-mh]").each(function () {
#                                         var b = c(this),
#                                             d = b.attr("data-mh") || b.attr("data-match-height");
#                                         a[d] = d in a ? a[d].add(b) : b;
#                                     });
#                                     c.each(a, function () {
#                                         this.matchHeight(!0);
#                                     });
#                                 };
#                                 var q = function (a) {
#                                     b._beforeUpdate && b._beforeUpdate(a, b._groups);
#                                     c.each(b._groups, function () {
#                                         b._apply(this.elements, this.options);
#                                     });
#                                     b._afterUpdate && b._afterUpdate(a, b._groups);
#                                 };
#                                 b._update = function (a, e) {
#                                     if (e && "resize" === e.type) {
#                                         var d = c(window).width();
#                                         if (d === n) return;
#                                         n = d;
#                                     }
#                                     a
#                                         ? -1 === f &&
#                                           (f = setTimeout(function () {
#                                               q(e);
#                                               f = -1;
#                                           }, b._throttle))
#                                         : q(e);
#                                 };
#                                 c(b._applyDataApi);
#                                 c(window).bind("load", function (a) {
#                                     b._update(!1, a);
#                                 });
#                                 c(window).bind("resize orientationchange", function (a) {
#                                     b._update(!0, a);
#                                 });
#                             })(jQuery);
#
#
#
#                             .main-intro-wrapper {
#                                 padding: 10px 10px 30px 10px;
#                                 background: #799734;
#                                 text-align: center;
#                                 color: #f0ffcc;
#                                 box-shadow: inset 0 -7px 9px -7px rgba(0, 0, 0, 0.7);
#                             }
#                             .curriculum-wrapper {
#                                 padding: 5px;
#                                 /*: url(https://sis.smu.edu.sg/sites/default/files/sis/programmes/MITB/images/diagonal_striped_brick2.jpg);
#                                 box-shadow: inset 0 -7px 9px -7px rgba(0,0,0,0.7);*/
#                             }
#                             .col-curriculum {
#                                 /*float: left;*/
#                                 width: 100%;
#                             }
#                             .col-curriculum-inner {
#                                 /*padding: 5px;*/
#                             }
#                             .main-icon-wrapper-a {
#                                 width: 25%;
#                                 float: left;
#                             }
#                             .main-icon-wrapper-b {
#                                 width: 25%;
#                                 float: left;
#                             }
#                             .item-wrapper-a {
#                                 width: 75%;
#                                 float: left;
#                                 padding: 5px;
#                             }
#                             .item-wrapper-b {
#                                 width: 75%;
#                                 float: left;
#                                 padding: 5px;
#                             }
#
#                             .col-curriculum-a {
#                                 background: #e6d5e9;
#                             }
#                             .col-curriculum-b {
#                                 background: #bbc3d6;
#                             }
#                             .col-curriculum-inner-b {
#                             }
#                             .col-curriculum-c {
#                                 background: #e7efcd;
#                             }
#                             .col-curriculum-inner-c {
#                             }
#                             .col-curriculum-d {
#                                 background: #d6d6d6;
#                             }
#                             .col-curriculum-inner-d {
#                             }
#                             .col-curriculum-e {
#                                 background: #efe4a3;
#                             }
#                             .col-curriculum-inner-e {
#                             }
#                             .col-curriculum-f {
#                                 background: #d9c8a3;
#                             }
#                             .curriculum-icon-title {
#                                 font-size: 18px;
#                                 font-family: "proxima-nova-extra-condensed", sans-serif;
#                                 font-weight: bold;
#                                 text-transform: uppercase;
#                             }
#                             .curriculum-box-wrapper {
#                                 width: 100%;
#                                 height: 70px;
#                                 padding: 10px;
#                                 margin-bottom: 15px;
#                                 -webkit-border-radius: 6px;
#                                 -moz-border-radius: 6px;
#                                 border-radius: 6px;
#                                 border: 2px solid;
#                                 font-size: 12px;
#                                 text-decoration: none !important;
#                                 color: #fff;
#                             }
#                             .curriculum-box-main {
#                                 /*height: 245px;*/
#                                 text-align: center;
#                                 padding: 10px;
#                                 color: #2d2e30;
#                             }
#                             .curriculum-icon-wrapper {
#                                 display: inline-block;
#                                 vertical-align: top;
#                             }
#                             .curriculum-icon {
#                                 max-width: 40%;
#                                 margin: 0 auto;
#                                 margin-bottom: 10px;
#                                 margin-top: 10px;
#                             }
#                             .curriculum-icon img {
#                                 width: 100%;
#                             }
#                             .btn-curriculum-box {
#                                 margin-bottom: 5px;
#                                 white-space: normal;
#                                 text-align: left;
#                                 color: #fff;
#                                 vertical-align: top;
#                                 width: 32.9%;
#                                 display: inline-block;
#                             }
#                             .btn-curriculum-box-a {
#                                 min-height: 60px;
#                                 background: #a177af;
#                                 border-color: #805b8d;
#                                 color: #fff;
#                             }
#                             .btn-curriculum-box-a:hover {
#                                 background: #805b8d;
#                                 color: #fff;
#                             }
#                             .btn-curriculum-box-b {
#                                 /*width: 100%;*/
#                                 min-height: 60px;
#                                 background: #4685b8;
#                                 border-color: #285baa;
#                                 color: #fff;
#                             }
#                             .btn-curriculum-box-b:hover {
#                                 background: #285baa;
#                                 color: #fff;
#                             }
#                             .btn-curriculum-box-c {
#                                 /*width: 100%;*/
#                                 min-height: 60px;
#                                 background: #a0bb61;
#                                 border-color: #799734;
#                                 color: #fff;
#                             }
#                             .btn-curriculum-box-c:hover {
#                                 background: #799734;
#                                 color: #fff;
#                             }
#                             .btn-curriculum-box-d {
#                                 /*width: 100%;*/
#                                 min-height: 60px;
#                                 background: #666666;
#                                 border-color: #414141;
#                                 color: #fff;
#                             }
#                             .btn-curriculum-box-d:hover {
#                                 background: #414141;
#                                 color: #fff;
#                             }
#                             .btn-curriculum-box-e {
#                                 /*width: 100%;*/
#                                 min-height: 60px;
#                                 background: #c5b54d;
#                                 border-color: #937527;
#                                 color: #fff;
#                             }
#                             .btn-curriculum-box-e:hover {
#                                 background: #937527;
#                                 color: #fff;
#                             }
#                             .btn-curriculum-box-f {
#                                 /*width: 100%;*/
#                                 min-height: 60px;
#                                 background: #987e46;
#                                 border-color: #7c6637;
#                                 color: #fff;
#                             }
#                             .btn-curriculum-box-f:hover {
#                                 background: #7c6637;
#                                 color: #fff;
#                             }
#                             .curriculum-prefix {
#                                 display: block;
#                                 font-family: "proxima-nova-extra-condensed", sans-serif;
#                                 font-size: 15px;
#                                 font-weight: bold;
#                                 text-transform: uppercase;
#                                 vertical-align: top;
#                             }
#                             .curriculum-text {
#                                 display: inline-block;
#                                 font-size: 12px;
#                                 vertical-align: top;
#                             }
#                             .curriculum-list-text {
#                                 padding-left: 15px;
#                             }
#                             .curriculum-info-wrapper {
#                                 float: left;
#                                 width: 50%;
#                             }
#                             .curriculum-info-inner {
#                                 padding: 10px;
#                                 margin: 10px;
#                                 background: #fff;
#                                 -webkit-border-radius: 6px;
#                                 -moz-border-radius: 6px;
#                                 border-radius: 6px;
#                                 border: 2px solid #a8a8a8;
#                             }
#                             .video-modal-embed-wrapper {
#                                 max-width: 600px;
#                             }
#                             .other-info-wrapper {
#                                 padding: 40px 15px 40px 15px;
#                                 background: url(https://sis.smu.edu.sg/sites/default/files/sis/programmes/MITB/images/congruent_pentagon2.jpg);
#                                 color: #fff;
#                             }
#                             .other-info-item-wrapper {
#                                 margin-bottom: 30px;
#                             }
#                             .other-info-header-wrapper {
#                                 float: left;
#                                 width: 20%;
#                             }
#                             .other-info-content-wrapper {
#                                 float: left;
#                                 width: 80%;
#                             }
#                             .other-info-content-inner {
#                                 margin-left: 15px;
#                                 padding-left: 15px;
#                             }
#                             .other-info-content-inner.gold {
#                                 border-left: 5px solid #d5a10d;
#                             }
#                             .other-info-content-inner.red {
#                                 border-left: 5px solid #e70509;
#                             }
#                             .other-info-content-inner.purple {
#                                 border-left: 5px solid #924cc5;
#                             }
#                             .other-info-content-inner.green {
#                                 border-left: 5px solid #8fcf50;
#                             }
#                             .programme-delivery-wrapper {
#                                 padding: 40px 15px 40px 15px;
#                                 background: rgba(255, 255, 255, 1);
#                                 background: -moz-linear-gradient(top, rgba(255, 255, 255, 1) 0%, rgba(246, 246, 246, 1) 47%, rgba(237, 237, 237, 1) 100%);
#                                 background: -webkit-gradient(left top, left bottom, color-stop(0%, rgba(255, 255, 255, 1)), color-stop(47%, rgba(246, 246, 246, 1)), color-stop(100%, rgba(237, 237, 237, 1)));
#                                 background: -webkit-linear-gradient(top, rgba(255, 255, 255, 1) 0%, rgba(246, 246, 246, 1) 47%, rgba(237, 237, 237, 1) 100%);
#                                 background: -o-linear-gradient(top, rgba(255, 255, 255, 1) 0%, rgba(246, 246, 246, 1) 47%, rgba(237, 237, 237, 1) 100%);
#                                 background: -ms-linear-gradient(top, rgba(255, 255, 255, 1) 0%, rgba(246, 246, 246, 1) 47%, rgba(237, 237, 237, 1) 100%);
#                                 background: linear-gradient(to bottom, rgba(255, 255, 255, 1) 0%, rgba(246, 246, 246, 1) 47%, rgba(237, 237, 237, 1) 100%);
#                                 filter: progid:DXImageTransform.Microsoft.gradient( startColorstr='#ffffff', endColorstr='#ededed', GradientType=0 );
#                                 box-shadow: inset 0 -7px 9px -7px rgba(0, 0, 0, 0.7);
#                             }
#                             .programme-delivery-item-wrapper {
#                                 float: left;
#                                 width: 50%;
#                                 margin-bottom: 30px;
#                             }
#                             .programme-delivery-item-inner {
#                                 padding: 15px;
#                                 text-align: center;
#                             }
#                             .programme-delivery-item-icon {
#                                 display: inline-block;
#                                 max-width: 125px;
#                                 margin-bottom: 15px;
#                             }
#                             .programme-delivery-item-icon img {
#                                 width: 100%;
#                             }
#                             .programme-delivery-item-content {
#                                 padding: 10px 15px;
#                                 background: #fff;
#                                 border: 2px solid #9bb5c8;
#                             }
#                             .career-wrapper {
#                             }
#                             .career-header-wrapper {
#                                 padding: 10px;
#                                 background: #0c5088;
#                                 border-bottom: 2px solid #0a416f;
#                                 text-align: center;
#                             }
#                             .career-content-wrapper {
#                                 padding: 15px;
#                                 background: #1365a9;
#                                 color: #fff;
#                             }
#                             .career-info-box-wrapper {
#                                 background: #164e7c;
#                                 -webkit-border-radius: 6px;
#                                 -moz-border-radius: 6px;
#                                 border-radius: 6px;
#                                 border: 2px solid #fff;
#                             }
#                             .career-info-box-inner {
#                                 padding: 15px;
#                                 color: #fff;
#                             }
#                             .btn-general {
#                                 background: #b48b12;
#                                 text-transform: uppercase;
#                                 color: #fff;
#                             }
#                             .btn-general:hover {
#                                 background: #906c04;
#                                 color: #fff;
#                             }
#                             .modal.modal-wide .modal-dialog {
#                                 width: 60%;
#                                 display: inline-block;
#                                 text-align: left;
#                                 vertical-align: middle;
#                             }
#                             .modal-wide .modal-body {
#                                 overflow-y: auto;
#                             }
#                             .modal {
#                                 text-align: center;
#                             }
#                             .clear {
#                                 clear: both;
#                             }
#                             .col-curriculum-internship {
#                                 padding: 15px;
#                                 background: #bf8f00;
#                                 color: #fff;
#                                 text-align: center;
#                             }
#                             .curriculum-text h4 {
#                                 font-size: 18px;
#                                 font-family: "proxima-nova-extra-condensed", sans-serif;
#                                 font-weight: bold;
#                                 text-transform: uppercase;
#                             }
#                             .curicullum-grad-wrapper {
#                                 margin: 15px 0;
#                             }
#                             .curicullum-grad-grid-wrapper {
#                                 border: 1px solid #828282;
#                                 margin-bottom: 15px;
#                             }
#                             .curicullum-grad-grid-title-wrapper {
#                                 padding: 12px;
#                                 text-align: center;
#                                 color: #000;
#                             }
#                             .curicullum-grad-grid-title-wrapper {
#                                 margin: 0;
#                                 font-size: 18px;
#                                 font-family: "proxima-nova-extra-condensed", sans-serif;
#                                 font-weight: bold;
#                                 text-transform: uppercase;
#                                 color: 000;
#                             }
#                             .curicullum-grad-grid-content-wrapper {
#                                 padding: 15px;
#                             }
#                             .curicullum-grad-grid-title-aux-wrapper {
#                                 margin-bottom: 12px;
#                                 font-size: 14px;
#                                 font-weight: bold;
#                                 color: #000;
#                             }
#                             .table-curicullum-data {
#                                 border-color: #ddd;
#                             }
#                             .table-curicullum-data tr td {
#                                 padding: 4px 8px;
#                             }
#                             .table-curicullum-data-header {
#                                 width: 325px;
#                                 font-weight: bold;
#                                 text-transform: uppercase;
#                                 color: #000;
#                             }
#                             .grad-gold {
#                                 background: #ffd966;
#                             }
#                             .grad-red {
#                                 background: #ff9999;
#                             }
#                             .grad-blue {
#                                 background: #bdd7ee;
#                             }
#                             .grad-green {
#                                 background: #a9d08e;
#                             }
#                             .grad-gray {
#                                 background: #d0cece;
#                             }
#                             .grad-purple {
#                                 background: #ddbcff;
#                             }
#                             .grad-darkgold {
#                                 background: #b98f3e;
#                             }
#                             .footnote-item {
#                                 position: relative;
#                                 padding-left: 15px;
#                             }
#                             .footnote-code {
#                                 position: absolute;
#                                 z-index: 1;
#                                 top: 0;
#                                 left: 0;
#                             }
#
#                             @media screen and (max-width: 1200px) {
#                                 .btn-curriculum-box {
#                                     width: 48.9%;
#                                 }
#                             }
#
#                             @media screen and (max-width: 999px) {
#                                 .main-icon-wrapper-a,
#                                 .main-icon-wrapper-b {
#                                     width: 100%;
#                                     float: none;
#                                 }
#                                 .item-wrapper-a,
#                                 .item-wrapper-b {
#                                     width: 100%;
#                                     float: none;
#                                 }
#                                 .modal.modal-wide .modal-dialog {
#                                     width: 80%;
#                                 }
#                             }
#
#                             @media screen and (min-width: 768px) {
#                                 .modal:before {
#                                     display: inline-block;
#                                     vertical-align: middle;
#                                     content: " ";
#                                     height: 100%;
#                                 }
#                             }
#
#                             @media screen and (max-width: 769px) {
#                                 .col-curriculum {
#                                     float: none;
#                                     width: 100%;
#                                     /*padding-bottom: 30px;*/
#                                     margin-bottom: 15px;
#                                     border-bottom: 1px solid #ccc;
#                                     text-align: center;
#                                 }
#                                 .col-curriculum-inner {
#                                     padding: 0;
#                                 }
#                                 .curriculum-box-main {
#                                     height: auto;
#                                     margin-bottom: 15px;
#                                 }
#                                 .btn-curriculum-box {
#                                     margin: 0;
#                                     width: 31.4%;
#                                     margin: 5px;
#                                 }
#                             }
#
#                             @media screen and (max-width: 601px) {
#                                 .other-info-header-wrapper,
#                                 .other-info-content-wrapper,
#                                 .curriculum-info-wrapper,
#                                 .programme-delivery-item-wrapper {
#                                     float: none;
#                                     width: 100%;
#                                 }
#                             }
#
#                             @media screen and (max-width: 361px) {
#                                 .btn-curriculum-box {
#                                     width: 100%;
#                                     margin: 5px;
#                                 }
#                             }
#
#
#                             jQuery(function () {
#                                 //Stop Video
#                                 jQuery("#curriculum-FT3").on("hidden.bs.modal", function (e) {
#                                     jQuery("#curriculum-FT3 iframe").attr("src", jQuery("#curriculum-FT3 iframe").attr("src"));
#                                 });
#
#                                 //Stop Video
#                                 jQuery("#curriculum-FT4").on("hidden.bs.modal", function (e) {
#                                     jQuery("#curriculum-FT4 iframe").attr("src", jQuery("#curriculum-FT4 iframe").attr("src"));
# ...
#
#
#                                                 The format of the class will be seminar presentation, case studies discussion and role plays to simulate real live situations (persuasion, building client trust and engagement in sourcing
#                                                 disputes, negotiations, board presentations etc)
#
#                                             Upon completion of the course, students will be able to:
#
#                                                 Understand the key factors influencing IT sourcing decisions
#                                                 Investigate the risks and tradeoffs involved in various forms of IT sourcing
#                                                 Analyze sourcing partner’s strength and weaknesses
#                                                 Understand key aspects of IT sourcing contracts
#                                                 Recognize the importance of inter-organisational relationship management and performance monitoring in global sourcing relationships
#                                                 Understand the impacts of outsourcing (both economic and social)
#                                                 Analyse sourcing trends and topical areas that the industry is trending towards
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                             IoT: Technology & Applications
#
#                                                 ×
#
#
#
#
#
#                                                 In the near future, we can envision a world in which billions of devices can sense, communicate, and collaborate over the Internet, in the same way that humans have interacted and collaborated
#                                                 with one another over the World Wide Web. This vision is now known as the Internet of Things. The knowledge created from these interconnected objects can potentially offer new anticipatory
#                                                 services to improve our quality of lives and can be applied to various application domains - such as smart cities, smart homes, logistics and healthcare. In line with worldwide efforts to
#                                                 realize smart cities through IoT technologies, this course is intended to equip students with the state-of-the-art in IoT technologies, to enable them to conceptualize practical IoT systems to
#                                                 realize citizen-centric applications.
#
#                                             Upon completion of the course, students will be able to:
#
#                                                 Define and understand what is IoT
#                                                 Describe the impact of IoT on society
#                                                 Evaluate the potential and feasibility of IoT applications for large-scale smart city applications
#                                                 Acquire knowledge and gain hands-on experience in state-of-the-art IoT component technologies – such as things, network connectivity and sense-making
#                                                 Conceptualize a sustainable and scalable end-to-end IoT system that generates actionable insights for stakeholders to solve real world problems
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                             Business Applications of Digital Technology
#
#                                                 ×
#
#
#
#
#
#                                                 Technologies play an important enabling role in digital transformation by improving efficiency and increasing productivity. As new disruptive know-hows continue to be developed, it is vital to
#                                                 keep up to date on the state-of-the-art knowledge in advanced science and digital technology. In this module, you will learn about use cases and best practices in enabling technologies such as
#                                                 data science, artificial intelligence, mobile and wearables, blockchain, 5G and communication technologies, cloud computing, IoT, social computing, and APIs/microservices.
#
#                                             Upon completion of the course, students will be able to:
#
#                                                 Understand the fundamentals of enabling digital technologies and their trends
#                                                 Apply digital technology drivers and use cases
#                                                 Select relevant digital technology for different business scenarios
#                                                 Assemble a suite of appropriate digital technologies to enable digital transformation
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                             Internship
#
#                                                 ×
#
#
#
#
#                                             The MITB Internship is an experiential learning experience for students to apply knowledge acquired in the MITB program within the professional setting. The internships are aligned with the aims of the MITB program and students’ respective tracks. It provides students with career-related work experience and understand how their skills and knowledge can be utilized in the industry. Students are able to demonstrate functioning knowledge, and identify areas of further development for their future careers. It also provides a chance for students to establish the professional network within the profession.
#                                             Upon completion of the internship, students will be able to:
#
#                                                 Identify their own strengths, interests, skills and career goals
#                                                 Discover the wide range of companies and functions available and the skills needed for job success
#                                                 Develop communication, interpersonal and other critical soft skills required on the job
#                                                 Develop the work ethic and skills required for success in the internship
#                                                 Build a record of internship experiences
#                                                 Identify, document, and carry out performance objectives related to the internship
#                                                 Build professional relationships with internship supervisors, mentors, learning buddies, and other colleagues
#                                                 Prepare an engaging, organized, and logical presentation summarizing the internship
#                                                 Receive guidance and professional support throughout the internship
#                                                 Demonstrate independence, responsibility, and time management
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                             Capstone Project
#
#                                                 ×
#
#
#
#
#                                             The MITB capstone project is an extensive, applied practice research project that is undertaken by students, supervised by SMU faculty members who have specific expertise and interest in the topic, and sometimes sponsored by external companies. It provides the students with an individualized learning experience to integrate and synthesize the skills, theories, and frameworks they have learnt in MITB programme. The project gives students an opportunity to delve in greater depth, into business challenges or topics in financial technologies, analytics, or AI field. Students shall identify a problem, develop the approach and methods needed to address the problem, and conduct the research and present the findings in both oral and written formats.
#                                             The capstone project experience aims to provide an authentic and practical interdisciplinary learning experience to take knowledge and theory they have learned in MITB and apply in a real-world setting. Upon completion of the capstone projects, students will be able to:
#
#                                                 Gain theoretical and practice insight, including background and new information on topics within the students’ respective tracks
#                                                 Locate, collect and/or generate information and data relevant to the project
#                                                 Develop critical thinking through reading, research, and hands-on analysis of the problem and dataset
#                                                 Evaluate the strengths and weaknesses of current research findings, techniques and methodologies
#                                                 Select, defend, and apply methodological approaches to answer the project’s questions
#                                                 Analyze the information and data, synthesize them to generate new knowledge and understanding
#                                                 Manage the research project, monitor its progress, refine, and pivot the approaches as needed
#                                                 Contribute to the development of academic or professional skills, techniques, tools, practices, ideas, theories or approaches
#                                                 Describe the limitations of the work, the complexity of knowledge, and of the potential contributions of interpretations and methods
#                                                 Present the project and its findings in an engaging, organized, and logical manner, summarizing the entire capstone project
#                                                 Receive guidance and professional support throughout the project
#                                                 Demonstrate independence, responsibility and time management
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Last updated on
#     05 May 2021  .
#
#
#
#
#
#
#
#
#
#
#
#
#   Analytics Track
# Artificial Intelligence Track
# Digital Transformation Track
# Financial Technology & Analytics Track
# MITB Graduate Pathways
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		Download the programme brochure
#
# 		Download
#
#
#
#
#
#
#
#
#
#
#
# Take the next step: Apply Now
# Join Our Mailing List
# Deposit Your Resume
#
#  Attend an Info Session
# Download Employment Report
#
#
#
#
#
#
#
#
#
#               Looking for something?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#        Terms of Use |
#       Privacy Statement  |
#       Personal Data Statement  |
#       Contact Data Protection Officer
#
#       © Copyright 2021 Singapore Management University. All Rights Reserved
#
#
#
#
#
#           Facebook
#
#            Instagram
#            Twitter
#
#            LinkedIn
#           YouTube
#           SoundCloud
#
#
#
#
#           SMU Blog
#
#            Telegram

# %%
course_names = soup.find_all("div",class_="curriculum-text")

# %%
course_names[3].get_text()
# Out:
# 'Digital Transformation in Retail Banking Technology'

# %%
list_courses=[]
for course_name in course_names:
    list_courses.append(course_name.get_text().strip())

# %%
for index,name in enumerate(list_courses):
    print(f"Course {index+1}: {name}")
# Out:
# Course 1: Digital Banking & Trends
# Course 2: Data Science in Financial Services*
# Course 3: Corporate Banking & Blockchain*
# Course 4: Digital Transformation in Retail Banking Technology
# Course 5: Financial Markets Systems & Technology
# Course 6: Digital Payments & Innovations
# Course 7: Fintech Innovations & Startups*
# Course 8: Quantum Computing in Financial Services*
# Course 9: RiskTech & RegTech
# Course 10: Data Management
# Course 11: Data Analytics Lab
# Course 12: Applied Statistical Analysis with R
# Course 13: Python Programming & Data Analysis
# Course 14: Customer Analytics & Applications* (SMU-X)
# Course 15: Operations Analytics & Applications
# Course 16: Big Data: Tools & Techniques
# Course 17: Visual Analytics & Applications
# Course 18: Text Analytics & Applications
# Course 19: Social Analytics & Applications
# Course 20: Process Analytics Using Simulation
# Course 21: Applied Machine Learning*
# Course 22: Data Science for Business*
# Course 23: Introduction to Artificial Intelligence*
# Course 24: Algorithm Design & Implementation
# Course 25: Applied Machine Learning*
# Course 26: Deep Learning for Visual Recognition*†
# Course 27: Natural Language Processing for Smart Assistants*
# Course 28: AI Planning & Decision Making*†
# Course 29: Multi-Agent Systems*†
# Course 30: Recommender Systems*
# Course 31: AI Translational Research Seminar§ (Without Credit)
# Course 32: Digital Transformation Strategy (SMU-X)
# Course 33: Digital Organisation & Change Management
# Course 34: Agile & DevSecOps
# Course 35: (digital) Product Management
# Course 36: Experimental Learning & Design Thinking
# Course 37: Digital Governance & Risk Management
# Course 38: Digital Enterprise Architecture
# Course 39: Cybersecurity Technology & Applications
# Course 40: Spreadsheet Modelling for Decision Making
# Course 41: IT Project & Vendor Management
# Course 42: Global Sourcing of Technology & Processes
# Course 43: IoT: Technology & Applications
# Course 44: Business Applications of Digital Technology
# Course 45: Internship
#                                                 (2 CUs)
# Course 46: Capstone Project
#                                                 (2 CUs)

# %% [markdown]
# ### Normalization

# %%
# Sample text
text = "The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war ? Is AI a bad thing ?"
print(text)
# Out:
# The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war ? Is AI a bad thing ?

# %%
# Convert to lowercase
text = text.lower() 
print(text)
# Out:
# the first time you see the second renaissance it may look boring. look at it at least twice and definitely watch part 2. it will change your view of the matrix. are the human people the ones who started the war ? is ai a bad thing ?

# %% [markdown]
# ### Punctuation Removal

# %%
import re

# Remove punctuation characters
text = re.sub(r"[^a-zA-Z0-9]"," ",text)
print(text)
# Out:
# the first time you see the second renaissance it may look boring  look at it at least twice and definitely watch part 2  it will change your view of the matrix  are the human people the ones who started the war   is ai a bad thing

# %% [markdown]
# ### Tokenization

# %%
# Split words into tokens(words)

words = text.split()
print(words)
# Out:
# ['the', 'first', 'time', 'you', 'see', 'the', 'second', 'renaissance', 'it', 'may', 'look', 'boring', 'look', 'at', 'it', 'at', 'least', 'twice', 'and', 'definitely', 'watch', 'part', '2', 'it', 'will', 'change', 'your', 'view', 'of', 'the', 'matrix', 'are', 'the', 'human', 'people', 'the', 'ones', 'who', 'started', 'the', 'war', 'is', 'ai', 'a', 'bad', 'thing']

# %% [markdown]
# ### NLTK: Natural Language ToolKit

# %%
import os
import nltk
nltk.data.path.append(os.path.join(os.getcwd(), "nltk_data"))

# %%
# Another sample text
text = "Dr. Smith graduated from the University of Washington. He later started an analytics firm called Lux, which catered to enterprise customers."
print(text)
# Out:
# Dr. Smith graduated from the University of Washington. He later started an analytics firm called Lux, which catered to enterprise customers.

# %%
from nltk.tokenize import word_tokenize

#split text into words using nltk
words = word_tokenize(text)
print(words)
# Out:
# ['Dr.', 'Smith', 'graduated', 'from', 'the', 'University', 'of', 'Washington', '.', 'He', 'later', 'started', 'an', 'analytics', 'firm', 'called', 'Lux', ',', 'which', 'catered', 'to', 'enterprise', 'customers', '.']

# %%
words2 = text.split()
print(words2)
# Out:
# ['Dr.', 'Smith', 'graduated', 'from', 'the', 'University', 'of', 'Washington.', 'He', 'later', 'started', 'an', 'analytics', 'firm', 'called', 'Lux,', 'which', 'catered', 'to', 'enterprise', 'customers.']

# %%
from nltk.tokenize import sent_tokenize

#split text into sentences using nltk
sentences = sent_tokenize(text)
print(sentences)
# Out:
# ['Dr. Smith graduated from the University of Washington.', 'He later started an analytics firm called Lux, which catered to enterprise customers.']

# %%
#List stop words
from nltk.corpus import stopwords
print(stopwords.words("english"))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %% [markdown]
# ### Proper way of doing it

# %%
# Reset text
text = "The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war ? Is AI a bad thing ?"

# Normalize it
text = re.sub(r"[^a-zA-Z0-9]"," ", text.lower())

# Tokenize it
words = word_tokenize(text)
#words= text.split()

# Remove stopwords
words = [word for word in words if word not in stopwords.words("english")]
print(words)
# Out:
# ['first', 'time', 'see', 'second', 'renaissance', 'may', 'look', 'boring', 'look', 'least', 'twice', 'definitely', 'watch', 'part', '2', 'change', 'view', 'matrix', 'human', 'people', 'ones', 'started', 'war', 'ai', 'bad', 'thing']

# %% [markdown]
# ### Parts of words tagging

# %%
from nltk import pos_tag

#tag parts of speech (pos)

words = word_tokenize("I really want to drink coffee and have some bread in the morning")
pos_tag(words)
# Out:
# [('I', 'PRP'),
#  ('really', 'RB'),
#  ('want', 'VBP'),
#  ('to', 'TO'),
#  ('drink', 'VB'),
#  ('coffee', 'NN'),
#  ('and', 'CC'),
#  ('have', 'VBP'),
#  ('some', 'DT'),
#  ('bread', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('morning', 'NN')]

# %% [markdown]
# ### Sentence Parsing

# %%
import nltk
# Define a custom grammar

my_grammer = nltk.CFG.fromstring("""
S -> NP VP
PP -> P NP
NP -> Det N | Det N PP | 'I'
VP -> V NP | VP PP
Det -> 'an' | 'my'
N -> 'elephant' | 'pajamas'
V -> 'shot'
P -> 'in'
"""
)

parser = nltk.ChartParser(my_grammer)

# %%
# Parse a sentence
sentence = word_tokenize("I shot an elephant in my pajamas")
for tree in parser.parse(sentence):
    print(tree)
# Out:
# (S
#   (NP I)
#   (VP
#     (VP (V shot) (NP (Det an) (N elephant)))
#     (PP (P in) (NP (Det my) (N pajamas)))))
# (S
#   (NP I)
#   (VP
#     (V shot)
#     (NP (Det an) (N elephant) (PP (P in) (NP (Det my) (N pajamas))))))

# %%
# Visualize parse trees
for tree in parser.parse(sentence):
    tree.draw()

# %% [markdown]
# ### Named entity recognition
#
# #### You have first to tokenize and tag parts of speech

# %%
from nltk import pos_tag, ne_chunk
from nltk.tokenize import word_tokenize

# Recognize named entities in a tagged sentence
ne_chunk(pos_tag(word_tokenize("I really want to drink coffee and have some bread in the morning.")))
# Out:
# The Ghostscript executable isn't found.
# See http://web.mit.edu/ghostscript/www/Install.htm
# If you're using a Mac, you can try installing
# https://docs.brew.sh/Installation then `brew install ghostscript`
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/nltk/tree.py in _repr_png_(self)
#     797                     [
# --> 798                         find_binary(
#     799                             "gs",
#
# ~/opt/anaconda3/lib/python3.8/site-packages/nltk/internals.py in find_binary(name, path_to_bin, env_vars, searchpath, binary_names, url, verbose)
#     687 ):
# --> 688     return next(
#     689         find_binary_iter(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/nltk/internals.py in find_binary_iter(name, path_to_bin, env_vars, searchpath, binary_names, url, verbose)
#     672     """
# --> 673     for file in find_file_iter(
#     674         path_to_bin or name, env_vars, searchpath, binary_names, url, verbose
#
# ~/opt/anaconda3/lib/python3.8/site-packages/nltk/internals.py in find_file_iter(filename, env_vars, searchpath, file_names, url, verbose, finding_dir)
#     631         div = "=" * 75
# --> 632         raise LookupError("\n\n%s\n%s\n%s" % (div, msg, div))
#     633
#
# LookupError:
#
# ===========================================================================
# NLTK was unable to find the gs file!
# Use software specific configuration paramaters or set the PATH environment variable.
# ===========================================================================
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/nltk/tree.py in _repr_png_(self)
#     815                 )
#     816                 print(pre_error_message, file=sys.stderr)
# --> 817                 raise LookupError
#     818
#     819             with open(out_path, "rb") as sr:
#
# LookupError:
# Tree('S', [('I', 'PRP'), ('really', 'RB'), ('want', 'VBP'), ('to', 'TO'), ('drink', 'VB'), ('coffee', 'NN'), ('and', 'CC'), ('have', 'VBP'), ('some', 'DT'), ('bread', 'NN'), ('in', 'IN'), ('the', 'DT'), ('morning', 'NN'), ('.', '.')])

# %% [markdown]
# ### Stemming
#
# ### Reduce the word to its root form

# %%
from nltk.stem.porter import PorterStemmer
from nltk.stem.snowball import SnowballStemmer

# %%
# Reduce words to their stems
stemmed = [PorterStemmer().stem(w) for w in words]
print(stemmed)
# Out:
# ['I', 'realli', 'want', 'to', 'drink', 'coffe', 'and', 'have', 'some', 'bread', 'in', 'the', 'morn']

# %% [markdown]
# ### Lemmatization
# ### Resulting form is also a meaningful word

# %%
from nltk.stem.wordnet import WordNetLemmatizer

# Reduce words to their root form
lemmed = [WordNetLemmatizer().lemmatize(w) for w in words]
print(lemmed)
# Out:
# ['I', 'really', 'want', 'to', 'drink', 'coffee', 'and', 'have', 'some', 'bread', 'in', 'the', 'morning']

# %%
# Lemmatize verbs by specifying pos
lemmed = [WordNetLemmatizer().lemmatize(w, pos='v') for w in lemmed]
print(lemmed)
# Out:
# ['I', 'really', 'want', 'to', 'drink', 'coffee', 'and', 'have', 'some', 'bread', 'in', 'the', 'morning']
